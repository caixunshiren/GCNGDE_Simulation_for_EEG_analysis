# %%
import os,sys,inspect
current_dir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parent_dir = os.path.dirname(current_dir)
sys.path.insert(1, parent_dir+r'\Covariance and Adjacency Matrix')
from DataManager import dataManager

# %%
import h5py
import numpy as np
filepath = parent_dir+'\datasets\sample_patients\pat_FR_620.mat'
variables = {}
f = h5py.File(filepath, 'r')
for k, v in f.items():
    variables[k] = np.array(v)
for key in variables.keys():
    print("name:", key)
    print("shape:", variables[key].shape)
    print("-----------------------")
#print sample EGG signal from one node
# Out:
# name: X_test
# shape: (640, 31, 1518)
# -----------------------
# name: X_train
# shape: (640, 31, 1395)
# -----------------------
# name: clip_sizes_test
# shape: (2, 129)
# -----------------------
# name: clip_sizes_train
# shape: (2, 127)
# -----------------------
# name: conv_sizes
# shape: (1, 1)
# -----------------------
# name: n_pre_szr
# shape: (1, 1)
# -----------------------
# name: sel_win_nums_test
# shape: (1, 1518)
# -----------------------
# name: sel_win_nums_train
# shape: (1, 1395)
# -----------------------
# name: soz_ch_ids
# shape: (5, 1)
# -----------------------
# name: stride_sec
# shape: (1, 1)
# -----------------------
# name: window_size_sec
# shape: (1, 1)
# -----------------------
# name: y_test
# shape: (1, 1518)
# -----------------------
# name: y_train
# shape: (1, 1395)
# -----------------------

# %%
dm = dataManager(variables["X_train"],variables["X_test"],variables["y_train"],variables["y_test"],10**(-4))
print("Indices below are removed as they are trivial data:")
print(dm.train_indices)
print(dm.test_indices)
# Out:
# --------data manager successfully initialized--------
# Indices below are removed as they are trivial data:
# [86, 87, 88, 89, 90, 1015, 1355, 1356]
# [242, 243, 247, 248, 249, 250, 251, 252, 253, 254, 255, 256, 257, 258, 459, 830, 862, 1056, 1057, 1058, 1059, 1060, 1061, 1062, 1063, 1064, 1065, 1066, 1067, 1367, 1394]

# %%
import torch
import torch.autograd
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
sys.path.insert(1, parent_dir+r'\Unsupervised GCN')
from GCN import *
from GCNutil import *

# %%
#first fine tune a good threshold n
n = 1*10**-3
dm.re_threshold(n)
show_heat_map(dm.A_train)
show_heat_map(create_DAD(dm.A_train))

# %%
model_dir = parent_dir+r'\Unsupervised GCN\models/2layer_1epoch_Aavg_1e-3.pt'
sim_train, sim_test = get_sim_matrix_from_model(dm, model_dir)
print(sim_train.shape)
print(sim_test.shape)
sim_train_arch = sim_train
sim_test_arch = sim_test
# Out:
# (1387, 31, 31)
# (1487, 31, 31)

# %%
#optional: normalize the sim_train and sim_test
mean = np.mean(sim_train)
sd = np.std(sim_train)
print(mean, sd)

sim_train = (sim_train - mean) / sd
sim_test = (sim_test - mean) / sd
# Out:
# 0.036376707 0.7148353

# %%
ictal_sum = np.zeros(sim_train[0][:,:].shape)
normal_sum = np.zeros(sim_train[0][:,:].shape)
tc = 0
ni = 0
nn = 0
for i in range(sim_train.shape[0]):
        if dm.Y_train[tc,0] == 1:
            ictal_sum = ictal_sum + sim_train[i,:,:]
            ni+=1
        else:
            normal_sum = normal_sum + sim_train[i,:,:]
            nn+=1
        tc+=1
ictal_sum = ictal_sum / ni
normal_sum = normal_sum / nn
print("average ictal")
show_heat_map(ictal_sum)
print("average normal")
show_heat_map(normal_sum)
# Out:
# average ictal
# average normal

# %%
from MLP import *

# %%
n_layers = 2
dropouts = [-1] + [x * 0.1 for x in range(3, 8)] # 6 choices
layer_factors = [0.8, 1, 2, 5, 10, 15, 20] # 7 choices
learning_rates = [1e-4, 3e-4]#, 1e-3, 3e-3, 1e-2, 3e-2]
print(dropouts)
print(layer_factors)
# Out:
# [-1, 0.30000000000000004, 0.4, 0.5, 0.6000000000000001, 0.7000000000000001]
# [0.8, 1, 2, 5, 10, 15, 20]

# %%
import itertools
def get_combs(n_layers, dropouts, layer_factors):
    layer_comb = []
    for f in layer_factors:
        for r in dropouts:
            layer_comb.append([f, r])

    d = []
    for i in range(n_layers):
        d.append(layer_comb)
    d = tuple(d)
    ret = [x for x in itertools.product(*d)]
    return ret

# %%
get_combs(2, [1,2], [5,6])
#import itertools
#print(list(itertools.permutations([1, 2, 3])))
# Out:
# [([5, 1], [5, 1]),
#  ([5, 1], [5, 2]),
#  ([5, 1], [6, 1]),
#  ([5, 1], [6, 2]),
#  ([5, 2], [5, 1]),
#  ([5, 2], [5, 2]),
#  ([5, 2], [6, 1]),
#  ([5, 2], [6, 2]),
#  ([6, 1], [5, 1]),
#  ([6, 1], [5, 2]),
#  ([6, 1], [6, 1]),
#  ([6, 1], [6, 2]),
#  ([6, 2], [5, 1]),
#  ([6, 2], [5, 2]),
#  ([6, 2], [6, 1]),
#  ([6, 2], [6, 2])]

# %%
parameter_list = []
for layers in range(1, n_layers+1):
    combs = get_combs(layers, dropouts, layer_factors)
    for c in combs:
        for lr in learning_rates:
            parameters = {
                'n_layers':layers,
                'layer_size_factor':[1]+[c[i][0] for i in range(1, len(c))], 
                'dropout':[t[1] for t in c],
                'batch_size': 128,
                'num_epochs': 250,
                'learning_rate': lr,
                'weight_decay': 5e-3,
                'betas': (0.9, 0.999), 
                'eps': 1e-08,
                'val_acc': None
            }
            parameter_list.append(parameters)

# %%
print(len(parameter_list))
# Out:
# 3612

# %%
#hyper_param_tuning starts here
from tqdm import tqdm
for parameters in tqdm(parameter_list):
    _, val_acc, epoch = train_MLP(dm, sim_train, sim_test, parameters, print_summary = True, verbose = False)
    parameters["val_acc"] = val_acc
    print("validation accuracy: ", round(val_acc, 3), "   Trained # epochs:", int(epoch))
# Out:
#   0%|          | 0/3612 [00:00<?, ?it/s]
# MLP(
#   (layers): ModuleList(
#     (0): Linear(in_features=496, out_features=1, bias=True)
#     (1): Sigmoid()
#   )
# )
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                    [-1, 1]             497
#            Sigmoid-2                    [-1, 1]               0
# ================================================================
# Total params: 497
# Trainable params: 497
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.00
# Estimated Total Size (MB): 0.01
# ----------------------------------------------------------------
#   0%|          | 1/3612 [00:07<7:18:02,  7.28s/it]
# validation accuracy:  0.551
# MLP(
#   (layers): ModuleList(
#     (0): Linear(in_features=496, out_features=1, bias=True)
#     (1): Sigmoid()
#   )
# )
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                    [-1, 1]             497
#            Sigmoid-2                    [-1, 1]               0
# ================================================================
# Total params: 497
# Trainable params: 497
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.00
# Estimated Total Size (MB): 0.01
# ----------------------------------------------------------------
#   0%|          | 2/3612 [00:14<7:18:21,  7.29s/it]
# validation accuracy:  0.561
# MLP(
#   (layers): ModuleList(
#     (0): Dropout(p=0.30000000000000004, inplace=False)
#     (1): Linear(in_features=496, out_features=1, bias=True)
#     (2): Sigmoid()
#   )
# )
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#            Dropout-1                  [-1, 496]               0
#             Linear-2                    [-1, 1]             497
#            Sigmoid-3                    [-1, 1]               0
# ================================================================
# Total params: 497
# Trainable params: 497
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.00
# Estimated Total Size (MB): 0.01
# ----------------------------------------------------------------
#   0%|          | 3/3612 [00:21<7:18:57,  7.30s/it]
# validation accuracy:  0.551
# MLP(
#   (layers): ModuleList(
#     (0): Dropout(p=0.30000000000000004, inplace=False)
#     (1): Linear(in_features=496, out_features=1, bias=True)
#     (2): Sigmoid()
#   )
# )
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#            Dropout-1                  [-1, 496]               0
#             Linear-2                    [-1, 1]             497
#            Sigmoid-3                    [-1, 1]               0
# ================================================================
# Total params: 497
# Trainable params: 497
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.00
# Estimated Total Size (MB): 0.01
# ----------------------------------------------------------------
#   0%|          | 4/3612 [00:29<7:23:56,  7.38s/it]
# validation accuracy:  0.576
# MLP(
#   (layers): ModuleList(
#     (0): Dropout(p=0.4, inplace=False)
#     (1): Linear(in_features=496, out_features=1, bias=True)
#     (2): Sigmoid()
#   )
# )
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#            Dropout-1                  [-1, 496]               0
#             Linear-2                    [-1, 1]             497
#            Sigmoid-3                    [-1, 1]               0
# ================================================================
# Total params: 497
# Trainable params: 497
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.00
# Estimated Total Size (MB): 0.01
# ----------------------------------------------------------------
#   0%|          | 5/3612 [00:37<7:35:28,  7.58s/it]
# validation accuracy:  0.53
# MLP(
#   (layers): ModuleList(
#     (0): Dropout(p=0.4, inplace=False)
#     (1): Linear(in_features=496, out_features=1, bias=True)
#     (2): Sigmoid()
#   )
# )
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#            Dropout-1                  [-1, 496]               0
#             Linear-2                    [-1, 1]             497
#            Sigmoid-3                    [-1, 1]               0
# ================================================================
# Total params: 497
# Trainable params: 497
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.00
# Estimated Total Size (MB): 0.01
# ----------------------------------------------------------------
#   0%|          | 6/3612 [00:45<7:41:15,  7.67s/it]
# validation accuracy:  0.574
# MLP(
#   (layers): ModuleList(
#     (0): Dropout(p=0.5, inplace=False)
#     (1): Linear(in_features=496, out_features=1, bias=True)
#     (2): Sigmoid()
#   )
# )
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#            Dropout-1                  [-1, 496]               0
#             Linear-2                    [-1, 1]             497
#            Sigmoid-3                    [-1, 1]               0
# ================================================================
# Total params: 497
# Trainable params: 497
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.00
# Estimated Total Size (MB): 0.01
# ----------------------------------------------------------------
#   0%|          | 7/3612 [00:53<7:40:50,  7.67s/it]
# validation accuracy:  0.469
# MLP(
#   (layers): ModuleList(
#     (0): Dropout(p=0.5, inplace=False)
#     (1): Linear(in_features=496, out_features=1, bias=True)
#     (2): Sigmoid()
#   )
# )
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#            Dropout-1                  [-1, 496]               0
#             Linear-2                    [-1, 1]             497
#            Sigmoid-3                    [-1, 1]               0
# ================================================================
# Total params: 497
# Trainable params: 497
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.00
# Estimated Total Size (MB): 0.01
# ----------------------------------------------------------------
#   0%|          | 8/3612 [01:00<7:36:16,  7.60s/it]
# validation accuracy:  0.522
# MLP(
#   (layers): ModuleList(
#     (0): Dropout(p=0.6000000000000001, inplace=False)
#     (1): Linear(in_features=496, out_features=1, bias=True)
#     (2): Sigmoid()
#   )
# )
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#            Dropout-1                  [-1, 496]               0
#             Linear-2                    [-1, 1]             497
#            Sigmoid-3                    [-1, 1]               0
# ================================================================
# Total params: 497
# Trainable params: 497
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.00
# Estimated Total Size (MB): 0.01
# ----------------------------------------------------------------
#   0%|          | 9/3612 [01:07<7:31:21,  7.52s/it]
# validation accuracy:  0.414
# MLP(
#   (layers): ModuleList(
#     (0): Dropout(p=0.6000000000000001, inplace=False)
#     (1): Linear(in_features=496, out_features=1, bias=True)
#     (2): Sigmoid()
#   )
# )
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#            Dropout-1                  [-1, 496]               0
#             Linear-2                    [-1, 1]             497
#            Sigmoid-3                    [-1, 1]               0
# ================================================================
# Total params: 497
# Trainable params: 497
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.00
# Estimated Total Size (MB): 0.01
# ----------------------------------------------------------------
#   0%|          | 9/3612 [01:11<7:59:00,  7.98s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-131-3b4167923e73> in <module>
#       2 from tqdm import tqdm
#       3 for parameters in tqdm(parameter_list):
# ----> 4     _, val_acc = train_MLP(dm, sim_train, sim_test, parameters, print_summary = True, verbose = False)
#       5     parameters["val_acc"] = val_acc
#       6     print("validation accuracy: ", round(val_acc, 3))
#
# ~\Documents\GitHub\GCNGDE_Simulation_for_EGG_analysis\Supervised MLP\MLP.py in train_MLP(dm, sim_train, sim_test, parameters, acc_fn, print_summary, verbose)
#     163
#     164             MLPmodel.eval()
# --> 165             val_pred = MLPmodel(batch_x_test)
#     166             val_loss = criterion(val_pred, batch_y_test)
#     167             val_acc = acc_fn(val_pred, batch_y_test, threshold=0.4)
#
# ~\anaconda3\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# ~\Documents\GitHub\GCNGDE_Simulation_for_EGG_analysis\Supervised MLP\MLP.py in forward(self, sim_matrices)
#      25
#      26     def forward(self, sim_matrices):
# ---> 27         x = self.flatten(sim_matrices)
#      28         for layer in self.layers:
#      29             x = layer(x)
#
# ~\Documents\GitHub\GCNGDE_Simulation_for_EGG_analysis\Supervised MLP\MLP.py in flatten(self, sim_matrices)
#      22     def flatten(self, sim_matrices):
#      23         tri_indices = torch.triu_indices(sim_matrices.shape[1], sim_matrices.shape[2])
# ---> 24         return sim_matrices[:, tri_indices[0, :], tri_indices[1, :]]
#      25
#      26     def forward(self, sim_matrices):
#
# KeyboardInterrupt:

# %%
import pandas as pd
param_list = pd.DataFrame(parameter_list)
#param_list = param_list.drop_duplicates()

# %%
print(param_list)
# Out:
#    n_layers layer_size_factor dropout  batch_size  num_epochs  learning_rate  \
# 0         1               [1]    [-1]         128         250         0.0001
# 1         1               [1]    [-1]         128         250         0.0003
#
#    weight_decay         betas           eps   val_acc
# 0         0.005  (0.9, 0.999)  1.000000e-08  0.557440
# 1         0.005  (0.9, 0.999)  1.000000e-08  0.579399
