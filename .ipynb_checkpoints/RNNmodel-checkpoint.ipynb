# %%
# %reload_ext autoreload
# %autoreload 2
#Custom Files
from DataManager import dataManager
from DataManagerUtil import *
import GCN as GCN
import GCNutil as GCNutil
import GDE as GDE
import GDEutil as GDEutil
import GDEsolvers as GDEsolvers
import MLP as MLP
from Full_model import Integrated_Model, Integrated_Model_RNN
import RNN as RNN

#Standard Libraries
# Torch
import torch
import torch.autograd
import torch.nn as nn
import torch.nn.functional as F
#Numpy
import numpy as np

# %%
#Loading everything from the dataset
filepath = 'datasets\pat_FR_620.mat' #264 253 620 273
variables = load_patient_data(filepath, verbose = True)
# Out:
# name: X_test
# shape: (640, 31, 1518)
# -----------------------
# name: X_train
# shape: (640, 31, 1395)
# -----------------------
# name: clip_sizes_test
# shape: (2, 129)
# -----------------------
# name: clip_sizes_train
# shape: (2, 127)
# -----------------------
# name: conv_sizes
# shape: (1, 1)
# -----------------------
# name: n_pre_szr
# shape: (1, 1)
# -----------------------
# name: sel_win_nums_test
# shape: (1, 1518)
# -----------------------
# name: sel_win_nums_train
# shape: (1, 1395)
# -----------------------
# name: soz_ch_ids
# shape: (5, 1)
# -----------------------
# name: stride_sec
# shape: (1, 1)
# -----------------------
# name: window_size_sec
# shape: (1, 1)
# -----------------------
# name: y_test
# shape: (1, 1518)
# -----------------------
# name: y_train
# shape: (1, 1395)
# -----------------------
# print sample EGG signal from one node:

# %%
dm = dataManager(variables["X_train"],variables["X_test"],variables["y_train"],variables["y_test"],10**(-4))
# Out:
# --------data manager successfully initialized--------

# %%
#reduce redundant nodes
#from DataManager import get_label_variance as glv
#print(glv(dm.X_train, dm.Y_train))
#print(np.argsort(glv(dm.X_train, dm.Y_train)))
print(dm)
dm.apply_dvariance_filter(28)
dm.mean_pooling_1d(size = 24, stride = 20, padding = 0)
print(dm)
# Out:
# X_train: shape of(1804, 50, 640)
# X_test: shape of(1830, 50, 640)
# Y_train: shape of(1804, 1)
# Y_test: shape of(1830, 1)
# A_train: shape of(50, 50)
# A_test: shape of(50, 50)
# P_avg_train: shape of(50, 50)
# P_avg_test: shape of(50, 50)
# --------data successfully filtered (dvariance)--------
# X_train: shape of(1804, 28, 31)
# X_test: shape of(1830, 28, 31)
# Y_train: shape of(1804, 1)
# Y_test: shape of(1830, 1)
# A_train: shape of(28, 28)
# A_test: shape of(28, 28)
# P_avg_train: shape of(28, 28)
# P_avg_test: shape of(28, 28)

# %%
show_heat_map(dm.P_avg_train)
show_heat_map(dm.conv_avg_train)

# %%
# adjacency generated by convariance
A2 = (dm.conv_avg_train > 10000)# + (dm.conv_avg_train < -8000) 
show_heat_map(A2)
show_heat_map(create_DAD(A2))

# %%
#randomly generated A
b = np.random.randint(-2000,2000,size=dm.conv_avg_train.shape)
A3 = (b + b.T)/2 > 1500
show_heat_map(A3)
show_heat_map(create_DAD(A3))

# %%
n = 0.0002#5*10**-3
dm.re_threshold(n)
show_heat_map(dm.A_train)
show_heat_map(create_DAD(dm.A_train))
#print(create_DAD(dm.A_train))
Araw =  dm.A_train

# %%
GCNparameters = {
    'body': dm.X_train.shape[2],
    'M': dm.X_train.shape[0],
    'batch_size': 256,
    'n_layers': 2,
    'num_epochs': 1,
    'learning_rate': 1e-3,
    'weight_decay': 5e-3
}
GDEparameters = {
    'body': dm.X_train.shape[2],
    'solver': GDEsolvers.explicit_RK,
    'solver_params': {
    "t0": 0,
    "t1": 0.25,
    "N": 5,
    "b_tableau": GDEsolvers.RK4
     },
    'hidden_layers': 1,
    'M': dm.X_train.shape[0],
    'batch_size': 128,
    'num_epochs': 1,
    'learning_rate': 1e-3,
    'weight_decay': 5e-3
}
RNNparametersGCN = {
    'hidden_dim' : 10,
    'batch_size': 128,
    'num_epochs': 800,
    'learning_rate': 6e-4,
    'weight_decay': 5e-3,
    'betas': (0.9, 0.999), 
    'eps': 1e-08
}
RNNparametersGDE = {
    'hidden_dim' : 10,
    'batch_size': 128,
    'num_epochs': 800,
    'learning_rate': 6e-4,
    'weight_decay': 5e-3,
    'betas': (0.9, 0.999), 
    'eps': 1e-08
}
#print(GCNparameters['M'])

# %%
IM = Integrated_Model_RNN(GCNparameters, GDEparameters, RNNparametersGCN, RNNparametersGDE, dm, create_DAD(Araw))
# Out:
#   0%|          | 0/6 [00:00<?, ?it/s]
# ----------Training GCN-----------
# device set to cpu
#  17%|█▋        | 1/6 [00:00<00:02,  1.75it/s]
# Epoch: 1   Batch: 1 of size 256   Train loss: 580.12548828125   Valid loss: 582.4777221679688
#  33%|███▎      | 2/6 [00:01<00:02,  1.71it/s]
# Epoch: 1   Batch: 2 of size 256   Train loss: 584.2261352539062   Valid loss: 577.934814453125
#  50%|█████     | 3/6 [00:01<00:01,  1.68it/s]
# Epoch: 1   Batch: 3 of size 256   Train loss: 578.4310302734375   Valid loss: 576.8040771484375
#  67%|██████▋   | 4/6 [00:02<00:01,  1.62it/s]
# Epoch: 1   Batch: 4 of size 256   Train loss: 576.7990112304688   Valid loss: 578.5260009765625
#  83%|████████▎ | 5/6 [00:03<00:00,  1.63it/s]
# Epoch: 1   Batch: 5 of size 256   Train loss: 578.9837036132812   Valid loss: 578.0148315429688
# 100%|██████████| 6/6 [00:03<00:00,  1.76it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
# Epoch: 1   Batch: 6 of size 256   Train loss: 578.6032104492188   Valid loss: 577.0118408203125
# ----------Training Ends-----------
# ----------Training GDE-----------
# device set to cpu
#   9%|▉         | 1/11 [00:13<02:17, 13.77s/it]
# Epoch: 1   Batch: 1 of size 128   Train loss: 580.4247436523438   Valid loss: 578.5015869140625
#  18%|█▊        | 2/11 [00:28<02:06, 14.08s/it]
# Epoch: 1   Batch: 2 of size 128   Train loss: 577.4415283203125   Valid loss: 579.1827392578125
#  27%|██▋       | 3/11 [00:41<01:48, 13.60s/it]
# Epoch: 1   Batch: 3 of size 128   Train loss: 577.3113403320312   Valid loss: 575.3040161132812
#  36%|███▋      | 4/11 [00:53<01:32, 13.25s/it]
# Epoch: 1   Batch: 4 of size 128   Train loss: 573.75732421875   Valid loss: 574.8414306640625
#  45%|████▌     | 5/11 [01:05<01:18, 13.03s/it]
# Epoch: 1   Batch: 5 of size 128   Train loss: 573.5796508789062   Valid loss: 575.5695190429688
AUC accuracy: 0.821
# device set to cuda
# threshold: 0.45  validation loss: 0.2506 F1 accuracy 0.606 Precision accuracy 0.956 Recall accuracy 0.443 AUC accuracy: 0.821
# device set to cuda
# threshold: 0.5  validation loss: 0.2506 F1 accuracy 0.601 Precision accuracy 0.955 Recall accuracy 0.438 AUC accuracy: 0.821
# device set to cuda
# threshold: 0.55  validation loss: 0.2506 F1 accuracy 0.595 Precision accuracy 0.976 Recall accuracy 0.428 AUC accuracy: 0.821
# device set to cuda
# threshold: 0.6  validation loss: 0.2506 F1 accuracy 0.59 Precision accuracy 0.976 Recall accuracy 0.423 AUC accuracy: 0.821
# device set to cuda
# threshold: 0.65  validation loss: 0.2506 F1 accuracy 0.559 Precision accuracy 0.974 Recall accuracy 0.392 AUC accuracy: 0.821
# device set to cuda
# threshold: 0.7  validation loss: 0.2506 F1 accuracy 0.543 Precision accuracy 0.973 Recall accuracy 0.376 AUC accuracy: 0.821
# device set to cuda
# threshold: 0.75  validation loss: 0.2506 F1 accuracy 0.532 Precision accuracy 0.973 Recall accuracy 0.366 AUC accuracy: 0.821
# device set to cuda
# threshold: 0.8  validation loss: 0.2506 F1 accuracy 0.506 Precision accuracy 0.985 Recall accuracy 0.34 AUC accuracy: 0.821
# device set to cuda
# threshold: 0.85  validation loss: 0.2506 F1 accuracy 0.471 Precision accuracy 0.984 Recall accuracy 0.309 AUC accuracy: 0.821
# device set to cuda
# threshold: 0.9  validation loss: 0.2506 F1 accuracy 0.435 Precision accuracy 1.0 Recall accuracy 0.278 AUC accuracy: 0.821
# device set to cuda
# threshold: 0.95  validation loss: 0.2506 F1 accuracy 0.089 Precision accuracy 1.0 Recall accuracy 0.046 AUC accuracy: 0.821
# device set to cuda

# %%
def save_ckp(state, f_path):
    torch.save(state, f_path)
    print("model saved")
def load_ckp(checkpoint_path):
    checkpoint = torch.load(checkpoint_path)
    return checkpoint
def load_RNNmodel(checkpoint, device_name ='cpu' ):
    if device_name == 'cuda':
        device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
        print("device set to cuda") if device == torch.device('cuda') else print("cuda is not available")
    elif device_name == 'cpu':
        device = torch.device('cpu')
        print("device set to cpu")
    else:
        device = torch.device('cpu')
        print("unknown device")
    
    parameters = checkpoint['parameters']
    model = RNN.RNN(dm.A_train.shape[1], 1, parameters['hidden_dim'], device = device).to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=parameters['learning_rate'],
                                 weight_decay=parameters['weight_decay'])
    model.load_state_dict(checkpoint['state_dict'])
    optimizer.load_state_dict(checkpoint['optimizer'])
    return model, optimizer

# %%
save_ckp(IM.RNNcheckpointGDE, "models/best_GDERNNmodel.pt")
save_ckp(IM.GDEcheckpoint, "models/best_GDEmodel.pt")
save_ckp(IM.RNNcheckpointGCN, "models/best_GCNRNNmodel.pt")
save_ckp(IM.GCNcheckpoint, "models/best_GCNmodel.pt")
# Out:
# model saved
# model saved
# model saved
# model saved

# %%
#try loading the model
checkpoint = load_ckp("models/best_GCNRNNmodel.pt")
RNNmodel, RNNoptimizer = load_RNNmodel(checkpoint, device_name ='cuda' )
# Out:
# device set to cuda

# %%
IM.RNNmodelGCN = RNNmodel

# %%
IM.print_accuracy(dm, Araw, device_name = 'cpu')
# Out:
# GCN accuracy:
# device set to cuda
# threshold: 0.05  validation loss: 0.5352 F1 accuracy 0.197 Precision accuracy 0.759 Recall accuracy 0.113 AUC accuracy: 0.742
# device set to cuda
# threshold: 0.1  validation loss: 0.5352 F1 accuracy 0.164 Precision accuracy 0.72 Recall accuracy 0.093 AUC accuracy: 0.742
# device set to cuda
# threshold: 0.15  validation loss: 0.5352 F1 accuracy 0.157 Precision accuracy 0.773 Recall accuracy 0.088 AUC accuracy: 0.742
# device set to cuda
# threshold: 0.2  validation loss: 0.5352 F1 accuracy 0.123 Precision accuracy 0.765 Recall accuracy 0.067 AUC accuracy: 0.742
# device set to cuda
# threshold: 0.25  validation loss: 0.5352 F1 accuracy 0.124 Precision accuracy 0.867 Recall accuracy 0.067 AUC accuracy: 0.742
# device set to cuda
# threshold: 0.3  validation loss: 0.5352 F1 accuracy 0.098 Precision accuracy 1.0 Recall accuracy 0.052 AUC accuracy: 0.742
# device set to cuda
# threshold: 0.35  validation loss: 0.5352 F1 accuracy 0.098 Precision accuracy 1.0 Recall accuracy 0.052 AUC accuracy: 0.742
# device set to cuda
# threshold: 0.4  validation loss: 0.5352 F1 accuracy 0.07 Precision accuracy 1.0 Recall accuracy 0.036 AUC accuracy: 0.742
# device set to cuda
# threshold: 0.45  validation loss: 0.5352 F1 accuracy 0.07 Precision accuracy 1.0 Recall accuracy 0.036 AUC accuracy: 0.742
# device set to cuda
# threshold: 0.5  validation loss: 0.5352 F1 accuracy 0.05 Precision accuracy 1.0 Recall accuracy 0.026 AUC accuracy: 0.742
# device set to cuda
# threshold: 0.55  validation loss: 0.5352 F1 accuracy 0.03 Precision accuracy 1.0 Recall accuracy 0.015 AUC accuracy: 0.742
# device set to cuda
# C:\Users\caixu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# threshold: 0.6  validation loss: 0.5352 F1 accuracy 0.0 Precision accuracy 0.0 Recall accuracy 0.0 AUC accuracy: 0.742
# device set to cuda
# threshold: 0.65  validation loss: 0.5352 F1 accuracy 0.0 Precision accuracy 0.0 Recall accuracy 0.0 AUC accuracy: 0.742
# device set to cuda
# threshold: 0.7  validation loss: 0.5352 F1 accuracy 0.0 Precision accuracy 0.0 Recall accuracy 0.0 AUC accuracy: 0.742
# device set to cuda
# threshold: 0.75  validation loss: 0.5352 F1 accuracy 0.0 Precision accuracy 0.0 Recall accuracy 0.0 AUC accuracy: 0.742
# device set to cuda
# threshold: 0.8  validation loss: 0.5352 F1 accuracy 0.0 Precision accuracy 0.0 Recall accuracy 0.0 AUC accuracy: 0.742
# device set to cuda
# threshold: 0.85  validation loss: 0.5352 F1 accuracy 0.0 Precision accuracy 0.0 Recall accuracy 0.0 AUC accuracy: 0.742
# device set to cuda
# threshold: 0.9  validation loss: 0.5352 F1 accuracy 0.0 Precision accuracy 0.0 Recall accuracy 0.0 AUC accuracy: 0.742
# device set to cuda
# threshold: 0.95  validation loss: 0.5352 F1 accuracy 0.0 Precision accuracy 0.0 Recall accuracy 0.0 AUC accuracy: 0.742
# device set to cuda
# GDE accuracy:
# device set to cuda
# threshold: 0.05  validation loss: 0.1573 F1 accuracy 0.868 Precision accuracy 0.767 Recall accuracy 1.0 AUC accuracy: 0.98
# device set to cuda
# threshold: 0.1  validation loss: 0.1573 F1 accuracy 0.87 Precision accuracy 0.77 Recall accuracy 1.0 AUC accuracy: 0.98
# device set to cuda
# threshold: 0.15  validation loss: 0.1573 F1 accuracy 0.87 Precision accuracy 0.77 Recall accuracy 1.0 AUC accuracy: 0.98
# device set to cuda
# threshold: 0.2  validation loss: 0.1573 F1 accuracy 0.87 Precision accuracy 0.77 Recall accuracy 1.0 AUC accuracy: 0.98
# device set to cuda
# threshold: 0.25  validation loss: 0.1573 F1 accuracy 0.873 Precision accuracy 0.778 Recall accuracy 0.995 AUC accuracy: 0.98
# device set to cuda
# threshold: 0.3  validation loss: 0.1573 F1 accuracy 0.874 Precision accuracy 0.786 Recall accuracy 0.985 AUC accuracy: 0.98
# device set to cuda
# threshold: 0.35  validation loss: 0.1573 F1 accuracy 0.872 Precision accuracy 0.785 Recall accuracy 0.979 AUC accuracy: 0.98
# device set to cuda
# threshold: 0.4  validation loss: 0.1573 F1 accuracy 0.871 Precision accuracy 0.787 Recall accuracy 0.974 AUC accuracy: 0.98
# device set to cuda
# threshold: 0.45  validation loss: 0.1573 F1 accuracy 0.87 Precision accuracy 0.79 Recall accuracy 0.969 AUC accuracy: 0.98
# device set to cuda
# threshold: 0.5  validation loss: 0.1573 F1 accuracy 0.87 Precision accuracy 0.792 Recall accuracy 0.964 AUC accuracy: 0.98
# device set to cuda
# threshold: 0.55  validation loss: 0.1573 F1 accuracy 0.867 Precision accuracy 0.791 Recall accuracy 0.959 AUC accuracy: 0.98
# device set to cuda
# threshold: 0.6  validation loss: 0.1573 F1 accuracy 0.867 Precision accuracy 0.791 Recall accuracy 0.959 AUC accuracy: 0.98
# device set to cuda
# threshold: 0.65  validation loss: 0.1573 F1 accuracy 0.862 Precision accuracy 0.79 Recall accuracy 0.948 AUC accuracy: 0.98
# device set to cuda
# threshold: 0.7  validation loss: 0.1573 F1 accuracy 0.856 Precision accuracy 0.788 Recall accuracy 0.938 AUC accuracy: 0.98
# device set to cuda
# threshold: 0.75  validation loss: 0.1573 F1 accuracy 0.856 Precision accuracy 0.79 Recall accuracy 0.933 AUC accuracy: 0.98
# device set to cuda
# threshold: 0.8  validation loss: 0.1573 F1 accuracy 0.848 Precision accuracy 0.788 Recall accuracy 0.918 AUC accuracy: 0.98
# device set to cuda
# threshold: 0.85  validation loss: 0.1573 F1 accuracy 0.842 Precision accuracy 0.786 Recall accuracy 0.907 AUC accuracy: 0.98
# device set to cuda
# threshold: 0.9  validation loss: 0.1573 F1 accuracy 0.83 Precision accuracy 0.784 Recall accuracy 0.881 AUC accuracy: 0.98
# device set to cuda
# threshold: 0.95  validation loss: 0.1573 F1 accuracy 0.789 Precision accuracy 0.77 Recall accuracy 0.809 AUC accuracy: 0.98
# device set to cuda
