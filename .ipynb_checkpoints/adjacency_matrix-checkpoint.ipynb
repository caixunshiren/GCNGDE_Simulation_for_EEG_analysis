# %%
# %reload_ext autoreload
# %autoreload 2
#Custom Files
from DataManager import dataManager
from DataManagerUtil import *
import GCN as GCN
import GCNutil as GCNutil
import GDE as GDE
import GDEutil as GDEutil
import GDEsolvers as GDEsolvers
import MLP as MLP
from Full_model import Integrated_Model

#Standard Libraries
# Torch
import torch
import torch.autograd
import torch.nn as nn
import torch.nn.functional as F
#Numpy
import numpy as np

# %%
#Loading everything from the dataset
filepath = 'datasets\pat_FR_620.mat' #264 253 620 273
variables = load_patient_data(filepath, verbose = True)
# Out:
# name: X_test
# shape: (640, 31, 1518)
# -----------------------
# name: X_train
# shape: (640, 31, 1395)
# -----------------------
# name: clip_sizes_test
# shape: (2, 129)
# -----------------------
# name: clip_sizes_train
# shape: (2, 127)
# -----------------------
# name: conv_sizes
# shape: (1, 1)
# -----------------------
# name: n_pre_szr
# shape: (1, 1)
# -----------------------
# name: sel_win_nums_test
# shape: (1, 1518)
# -----------------------
# name: sel_win_nums_train
# shape: (1, 1395)
# -----------------------
# name: soz_ch_ids
# shape: (5, 1)
# -----------------------
# name: stride_sec
# shape: (1, 1)
# -----------------------
# name: window_size_sec
# shape: (1, 1)
# -----------------------
# name: y_test
# shape: (1, 1518)
# -----------------------
# name: y_train
# shape: (1, 1395)
# -----------------------
# print sample EGG signal from one node:

# %%
dm = dataManager(variables["X_train"],variables["X_test"],variables["y_train"],variables["y_test"],10**(-4))
# Out:
# --------data manager successfully initialized--------

# %%
#reduce redundant nodes
#from DataManager import get_label_variance as glv
#print(glv(dm.X_train, dm.Y_train))
#print(np.argsort(glv(dm.X_train, dm.Y_train)))
print(dm)
dm.apply_dvariance_filter(28)
dm.mean_pooling_1d(size = 24, stride = 20, padding = 0)
#dm.normalize()
print(dm)
# Out:
# X_train: shape of(1387, 31, 640)
# X_test: shape of(1487, 31, 640)
# Y_train: shape of(1387, 1)
# Y_test: shape of(1487, 1)
# A_train: shape of(31, 31)
# A_test: shape of(31, 31)
# P_avg_train: shape of(31, 31)
# P_avg_test: shape of(31, 31)
# --------data successfully filtered (dvariance)--------
# X_train: shape of(1387, 28, 31)
# X_test: shape of(1487, 28, 31)
# Y_train: shape of(1387, 1)
# Y_test: shape of(1487, 1)
# A_train: shape of(28, 28)
# A_test: shape of(28, 28)
# P_avg_train: shape of(28, 28)
# P_avg_test: shape of(28, 28)

# %%
show_heat_map(dm.P_avg_train)
show_heat_map(dm.conv_avg_train)

# %%
# adjacency generated by convariance
A2 = (dm.conv_avg_train > 10000)# + (dm.conv_avg_train < -8000) 
show_heat_map(A2)
show_heat_map(create_DAD(A2))

# %%
#randomly generated A
b = np.random.randint(-2000,2000,size=dm.conv_avg_train.shape)
A3 = (b + b.T)/2 > 1500
show_heat_map(A3)
show_heat_map(create_DAD(A3))

# %%
n = 0.1#1.3*10**-2
dm.re_threshold(n)
show_heat_map(dm.A_train)
show_heat_map(create_DAD(dm.A_train))
#print(create_DAD(dm.A_train))
Araw =  dm.A_train

# %%
GCNparameters = {
    'body': dm.X_train.shape[2],
    'M': dm.X_train.shape[0],
    'batch_size': 256,
    'n_layers': 2,
    'num_epochs': 5,
    'learning_rate': 1e-3,
    'weight_decay': 5e-3
}
GDEparameters = {
    'body': dm.X_train.shape[2],
    'solver': GDEsolvers.explicit_RK,
    'solver_params': {
    "t0": 0,
    "t1": 1,
    "N": 20,
    "b_tableau": GDEsolvers.RK4
     },
    'hidden_layers': 1,
    'M': dm.X_train.shape[0],
    'batch_size': 128,
    'num_epochs': 1,
    'learning_rate': 1e-3,
    'weight_decay': 5e-3
}
MLPparametersGCN = {
    'n_layers':2,
    'layer_size_factor':[1,50], 
    'dropout':[0.3, 0.15],
    'batch_size': 128,
    'num_epochs': 900,
    'learning_rate': 6e-4,
    'weight_decay': 5e-3,
    'betas': (0.9, 0.999), 
    'eps': 1e-08
}
MLPparametersGDE = {
    'n_layers':2,
    'layer_size_factor':[1, 50], 
    'dropout':[0.3, 0.15],
    'batch_size': 128,
    'num_epochs': 900,
    'learning_rate': 6e-4,
    'weight_decay': 5e-3,
    'betas': (0.9, 0.999), 
    'eps': 1e-08
}
#print(GCNparameters['M'])

# %%
IM = Integrated_Model(GCNparameters, GDEparameters, MLPparametersGCN, MLPparametersGDE, dm, create_DAD(Araw))
# Out:
# 100%|██████████| 6/6 [00:00<00:00, 48.13it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# ----------Training GCN-----------
# device set to cpu
# Epoch: 1   Batch: 6 of size 256   Train loss: 386.58172607421875   Valid loss: 385.9040832519531
# Epoch: 2   Batch: 1 of size 256   Train loss: 385.8890380859375   Valid loss: 385.2708435058594
# 100%|██████████| 6/6 [00:00<00:00, 40.38it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# Epoch: 2   Batch: 6 of size 256   Train loss: 382.28369140625   Valid loss: 381.778625488281259
# Epoch: 3   Batch: 3 of size 256   Train loss: 380.57867431640625   Valid loss: 380.4332580566406
# 100%|██████████| 6/6 [00:00<00:00, 46.64it/s]
# 100%|██████████| 6/6 [00:00<00:00, 47.00it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# Epoch: 3   Batch: 6 of size 256   Train loss: 378.9283752441406   Valid loss: 379.42089843755
# Epoch: 4   Batch: 6 of size 256   Train loss: 377.0163879394531   Valid loss: 378.710021972656255
# 100%|██████████| 6/6 [00:00<00:00, 39.84it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
# Epoch: 5   Batch: 6 of size 256   Train loss: 375.94036865234375   Valid loss: 378.8163146972656
# ----------Training Ends-----------
# ----------Training GDE-----------
# device set to cpu
#   9%|▉         | 1/11 [00:00<00:07,  1.35it/s]
# Epoch: 1   Batch: 1 of size 128   Train loss: 393.8025207519531   Valid loss: 392.39776611328125
#  18%|█▊        | 2/11 [00:01<00:06,  1.36it/s]
# Epoch: 1   Batch: 2 of size 128   Train loss: 392.3626708984375   Valid loss: 391.1556091308594
#  27%|██▋       | 3/11 [00:02<00:05,  1.35it/s]
# Epoch: 1   Batch: 3 of size 128   Train loss: 390.98968505859375   Valid loss: 389.9512939453125
#  36%|███▋      | 4/11 [00:02<00:05,  1.34it/s]
# Epoch: 1   Batch: 4 of size 128   Train loss: 389.6993408203125   Valid loss: 388.8768310546875
#  45%|████▌     | 5/11 [00:03<00:04,  1.34it/s]
# Epoch: 1   Batch: 5 of size 128   Train loss: 388.5238037109375   Valid loss: 387.7505798339844
#  55%|█████▍    | 6/11 [00:04<00:03,  1.34it/s]
# Epoch: 1   Batch: 6 of size 128   Train loss: 387.35809326171875   Valid loss: 386.79986572265625
#  64%|██████▎   | 7/11 [00:05<00:03,  1.33it/s]
# Epoch: 1   Batch: 7 of size 128   Train loss: 386.375732421875   Valid loss: 385.6820983886719
#  73%|███████▎  | 8/11 [00:05<00:02,  1.33it/s]
# Epoch: 1   Batch: 8 of size 128   Train loss: 385.3407897949219   Valid loss: 384.8085021972656
#  82%|████████▏ | 9/11 [00:06<00:01,  1.34it/s]
# Epoch: 1   Batch: 9 of size 128   Train loss: 384.4967956542969   Valid loss: 384.2073974609375
#  91%|█████████ | 10/11 [00:07<00:00,  1.35it/s]
# Epoch: 1   Batch: 10 of size 128   Train loss: 383.6033630371094   Valid loss: 383.4107666015625
# 100%|██████████| 11/11 [00:08<00:00,  1.36it/s]
# Epoch: 1   Batch: 11 of size 128   Train loss: 382.630859375   Valid loss: 382.4832763671875
# ----------Training Ends-----------
# Average Ictal and Non-Ictal Simularity Matrix for GCN
# Average ictal
# Average Non-Ictal
# Average Ictal and Non-Ictal Simularity Matrix for GDE
# Average ictal
# Average Non-Ictal
# Sample Ictal and Non-Ictal Simularity Matrix for GCN
# sample ictal
# sample Non-Ictal
# Sample Ictal and Non-Ictal Simularity Matrix for GDE
# sample ictal
# sample Non-Ictal
# ----------Training MLP-----------
# 0.549 ----------saved-----------
# 0.655 ----------saved-----------
# 0.702 ----------saved-----------
# 0.727 ----------saved-----------
# 0.742 ----------saved-----------
# 0.756 ----------saved-----------
# 0.768 ----------saved-----------
# 0.777 ----------saved-----------
# 0.782 ----------saved-----------
# 0.787 ----------saved-----------
# 0.792 ----------saved-----------
# 0.795 ----------saved-----------
# 0.797 ----------saved-----------
# 0.798 ----------saved-----------
# 0.799 ----------saved-----------
# 0.799 ----------saved-----------
# 0.799 ----------saved-----------
# 0.8 ----------saved-----------
# 0.801 ----------saved-----------
# 0.801 ----------saved-----------
# 0.802 ----------saved-----------
# 0.803 ----------saved-----------
# 0.804 ----------saved-----------
# ----------------------------------
# 0.594 ----------saved-----------
# 0.64 ----------saved-----------
# 0.672 ----------saved-----------
# 0.691 ----------saved-----------
# 0.705 ----------saved-----------
# 0.715 ----------saved-----------
# 0.723 ----------saved-----------
# 0.73 ----------saved-----------
# 0.737 ----------saved-----------
# 0.744 ----------saved-----------
# 0.75 ----------saved-----------
# 0.757 ----------saved-----------
# 0.763 ----------saved-----------
# 0.768 ----------saved-----------
# 0.772 ----------saved-----------
# 0.776 ----------saved-----------
# 0.78 ----------saved-----------
# 0.782 ----------saved-----------
# 0.786 ----------saved-----------
# 0.79 ----------saved-----------
# 0.792 ----------saved-----------
# 0.795 ----------saved-----------
# 0.796 ----------saved-----------
# 0.799 ----------saved-----------
# 0.801 ----------saved-----------
# 0.802 ----------saved-----------
# 0.803 ----------saved-----------
# 0.804 ----------saved-----------
# 0.804 ----------saved-----------
# ----------Training Ends-----------

# %%
IM.print_accuracy(dm, Araw, device_name = 'cpu')
# Out:
# GCN accuracy:
# device set to cuda
# threshold: 0.05  validation loss: 0.3517 F1 accuracy 0.263 Precision accuracy 0.152 Recall accuracy 0.959 AUC accuracy: 0.788
# device set to cuda
# threshold: 0.1  validation loss: 0.3517 F1 accuracy 0.418 Precision accuracy 0.3 Recall accuracy 0.691 AUC accuracy: 0.788
# device set to cuda
# threshold: 0.15  validation loss: 0.3517 F1 accuracy 0.358 Precision accuracy 0.5 Recall accuracy 0.278 AUC accuracy: 0.788
# device set to cuda
# threshold: 0.2  validation loss: 0.3517 F1 accuracy 0.13 Precision accuracy 0.667 Recall accuracy 0.072 AUC accuracy: 0.788
# device set to cuda
# threshold: 0.25  validation loss: 0.3517 F1 accuracy 0.04 Precision accuracy 0.667 Recall accuracy 0.021 AUC accuracy: 0.788
# device set to cuda
# threshold: 0.3  validation loss: 0.3517 F1 accuracy 0.04 Precision accuracy 1.0 Recall accuracy 0.021 AUC accuracy: 0.788
# device set to cuda
# threshold: 0.35  validation loss: 0.3517 F1 accuracy 0.03 Precision accuracy 1.0 Recall accuracy 0.015 AUC accuracy: 0.788
# device set to cuda
# threshold: 0.4  validation loss: 0.3517 F1 accuracy 0.02 Precision accuracy 1.0 Recall accuracy 0.01 AUC accuracy: 0.788
# device set to cuda
# threshold: 0.45  validation loss: 0.3517 F1 accuracy 0.01 Precision accuracy 1.0 Recall accuracy 0.005 AUC accuracy: 0.788
# device set to cuda
# threshold: 0.5  validation loss: 0.3517 F1 accuracy 0.01 Precision accuracy 1.0 Recall accuracy 0.005 AUC accuracy: 0.788
# device set to cuda
# threshold: 0.55  validation loss: 0.3517 F1 accuracy 0.01 Precision accuracy 1.0 Recall accuracy 0.005 AUC accuracy: 0.788
# device set to cuda
# threshold: 0.6  validation loss: 0.3517 F1 accuracy 0.0 Precision accuracy 0.0 Recall accuracy 0.0 AUC accuracy: 0.788
# device set to cuda
# threshold: 0.65  validation loss: 0.3517 F1 accuracy 0.0 Precision accuracy 0.0 Recall accuracy 0.0 AUC accuracy: 0.788
# device set to cuda
# threshold: 0.7  validation loss: 0.3517 F1 accuracy 0.0 Precision accuracy 0.0 Recall accuracy 0.0 AUC accuracy: 0.788
# device set to cuda
# threshold: 0.75  validation loss: 0.3517 F1 accuracy 0.0 Precision accuracy 0.0 Recall accuracy 0.0 AUC accuracy: 0.788
# device set to cuda
# threshold: 0.8  validation loss: 0.3517 F1 accuracy 0.0 Precision accuracy 0.0 Recall accuracy 0.0 AUC accuracy: 0.788
# device set to cuda
# threshold: 0.85  validation loss: 0.3517 F1 accuracy 0.0 Precision accuracy 0.0 Recall accuracy 0.0 AUC accuracy: 0.788
# device set to cuda
# threshold: 0.9  validation loss: 0.3517 F1 accuracy 0.0 Precision accuracy 0.0 Recall accuracy 0.0 AUC accuracy: 0.788
# device set to cuda
# threshold: 0.95  validation loss: 0.3517 F1 accuracy 0.0 Precision accuracy 0.0 Recall accuracy 0.0 AUC accuracy: 0.788
# device set to cuda
# GDE accuracy:
# device set to cuda
# threshold: 0.05  validation loss: 0.3474 F1 accuracy 0.26 Precision accuracy 0.149 Recall accuracy 0.985 AUC accuracy: 0.803
# device set to cuda
# threshold: 0.1  validation loss:
# C:\Users\caixu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\caixu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 0.3474 F1 accuracy 0.394 Precision accuracy 0.273 Recall accuracy 0.706 AUC accuracy: 0.803
# device set to cuda
# threshold: 0.15  validation loss: 0.3474 F1 accuracy 0.469 Precision accuracy 0.637 Recall accuracy 0.371 AUC accuracy: 0.803
# device set to cuda
# threshold: 0.2  validation loss: 0.3474 F1 accuracy 0.17 Precision accuracy 0.655 Recall accuracy 0.098 AUC accuracy: 0.803
# device set to cuda
# threshold: 0.25  validation loss: 0.3474 F1 accuracy 0.04 Precision accuracy 0.667 Recall accuracy 0.021 AUC accuracy: 0.803
# device set to cuda
# threshold: 0.3  validation loss: 0.3474 F1 accuracy 0.0 Precision accuracy 0.0 Recall accuracy 0.0 AUC accuracy: 0.803
# device set to cuda
# threshold: 0.35  validation loss: 0.3474 F1 accuracy 0.0 Precision accuracy 0.0 Recall accuracy 0.0 AUC accuracy: 0.803
# device set to cuda
# threshold: 0.4  validation loss: 0.3474 F1 accuracy 0.0 Precision accuracy 0.0 Recall accuracy 0.0 AUC accuracy: 0.803
# device set to cuda
# threshold: 0.45  validation loss: 0.3474 F1 accuracy 0.0 Precision accuracy 0.0 Recall accuracy 0.0 AUC accuracy: 0.803
# device set to cuda
# threshold: 0.5  validation loss: 0.3474 F1 accuracy 0.0 Precision accuracy 0.0 Recall accuracy 0.0 AUC accuracy: 0.803
# device set to cuda
# threshold: 0.55  validation loss: 0.3474 F1 accuracy 0.0 Precision accuracy 0.0 Recall accuracy 0.0 AUC accuracy: 0.803
# device set to cuda
# threshold: 0.6  validation loss: 0.3474 F1 accuracy 0.0 Precision accuracy 0.0 Recall accuracy 0.0 AUC accuracy: 0.803
# device set to cuda
# threshold: 0.65  validation loss: 0.3474 F1 accuracy 0.0 Precision accuracy 0.0 Recall accuracy 0.0 AUC accuracy: 0.803
# device set to cuda
# threshold: 0.7  validation loss: 0.3474 F1 accuracy 0.0 Precision accuracy 0.0 Recall accuracy 0.0 AUC accuracy: 0.803
# device set to cuda
# threshold: 0.75  validation loss: 0.3474 F1 accuracy 0.0 Precision accuracy 0.0 Recall accuracy 0.0 AUC accuracy: 0.803
# device set to cuda
# threshold: 0.8  validation loss: 0.3474 F1 accuracy 0.0 Precision accuracy 0.0 Recall accuracy 0.0 AUC accuracy: 0.803
# device set to cuda
# threshold: 0.85  validation loss: 0.3474 F1 accuracy 0.0 Precision accuracy 0.0 Recall accuracy 0.0 AUC accuracy: 0.803
# device set to cuda
# threshold: 0.9  validation loss: 0.3474 F1 accuracy 0.0 Precision accuracy 0.0 Recall accuracy 0.0 AUC accuracy: 0.803
# device set to cuda
# threshold: 0.95  validation loss: 0.3474 F1 accuracy 0.0 Precision accuracy 0.0 Recall accuracy 0.0 AUC accuracy: 0.803
# device set to cuda
