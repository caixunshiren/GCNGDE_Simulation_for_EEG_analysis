# %% [markdown]
# ## This notebook explores different ways to generate adjacency matrix

# %%
# %reload_ext autoreload
# %autoreload 2
#Custom Files
from DataManager import dataManager
from DataManagerUtil import *
import GCN as GCN
import GCNutil as GCNutil
import GDE as GDE
import GDEutil as GDEutil
import GDEsolvers as GDEsolvers
import MLP as MLP
from Full_model import Integrated_Model

#Standard Libraries
# Torch
import torch
import torch.autograd
import torch.nn as nn
import torch.nn.functional as F
#Numpy
import numpy as np

# %%
#Loading everything from the dataset
filepath = 'datasets\pat_FR_620.mat' #264 253 620 273
variables = load_patient_data(filepath, verbose = True)
# Out:
# name: X_test
# shape: (640, 31, 1518)
# -----------------------
# name: X_train
# shape: (640, 31, 1395)
# -----------------------
# name: clip_sizes_test
# shape: (2, 129)
# -----------------------
# name: clip_sizes_train
# shape: (2, 127)
# -----------------------
# name: conv_sizes
# shape: (1, 1)
# -----------------------
# name: n_pre_szr
# shape: (1, 1)
# -----------------------
# name: sel_win_nums_test
# shape: (1, 1518)
# -----------------------
# name: sel_win_nums_train
# shape: (1, 1395)
# -----------------------
# name: soz_ch_ids
# shape: (5, 1)
# -----------------------
# name: stride_sec
# shape: (1, 1)
# -----------------------
# name: window_size_sec
# shape: (1, 1)
# -----------------------
# name: y_test
# shape: (1, 1518)
# -----------------------
# name: y_train
# shape: (1, 1395)
# -----------------------
# print sample EGG signal from one node:

# %%
dm = dataManager(variables["X_train"],variables["X_test"],variables["y_train"],variables["y_test"],10**(-4))
# Out:
# --------data manager successfully initialized--------

# %%
#reduce redundant nodes
#from DataManager import get_label_variance as glv
#print(glv(dm.X_train, dm.Y_train))
#print(np.argsort(glv(dm.X_train, dm.Y_train)))
print(dm)
dm.apply_dvariance_filter(28)
dm.mean_pooling_1d(size = 24, stride = 20, padding = 0)
#dm.normalize()
print(dm)
# Out:
# X_train: shape of(1387, 31, 640)
# X_test: shape of(1487, 31, 640)
# Y_train: shape of(1387, 1)
# Y_test: shape of(1487, 1)
# A_train: shape of(31, 31)
# A_test: shape of(31, 31)
# P_avg_train: shape of(31, 31)
# P_avg_test: shape of(31, 31)
# --------data successfully filtered (dvariance)--------
# X_train: shape of(1387, 28, 31)
# X_test: shape of(1487, 28, 31)
# Y_train: shape of(1387, 1)
# Y_test: shape of(1487, 1)
# A_train: shape of(28, 28)
# A_test: shape of(28, 28)
# P_avg_train: shape of(28, 28)
# P_avg_test: shape of(28, 28)

# %%
show_heat_map(dm.P_avg_train)
show_heat_map(dm.conv_avg_train)

# %%
# adjacency generated by convariance
A2 = (dm.conv_avg_train > 10000)# + (dm.conv_avg_train < -8000) 
show_heat_map(A2)
show_heat_map(create_DAD(A2))

# %%
#randomly generated A
b = np.random.randint(-2000,2000,size=dm.conv_avg_train.shape)
A3 = (b + b.T)/2 > 1500
show_heat_map(A3)
show_heat_map(create_DAD(A3))

# %%
n = 0.1#1.3*10**-2
dm.re_threshold(n)
show_heat_map(dm.A_train)
show_heat_map(create_DAD(dm.A_train))
#print(create_DAD(dm.A_train))
Araw =  dm.A_train

# %%
GCNparameters = {
    'body': dm.X_train.shape[2],
    'M': dm.X_train.shape[0],
    'batch_size': 256,
    'n_layers': 2,
    'num_epochs': 5,
    'learning_rate': 1e-3,
    'weight_decay': 5e-3
}
GDEparameters = {
    'body': dm.X_train.shape[2],
    'solver': GDEsolvers.explicit_RK,
    'solver_params': {
    "t0": 0,
    "t1": 1,
    "N": 20,
    "b_tableau": GDEsolvers.RK4
     },
    'hidden_layers': 1,
    'M': dm.X_train.shape[0],
    'batch_size': 128,
    'num_epochs': 1,
    'learning_rate': 1e-3,
    'weight_decay': 5e-3
}
MLPparametersGCN = {
    'n_layers':2,
    'layer_size_factor':[1,50], 
    'dropout':[0.3, 0.15],
    'batch_size': 128,
    'num_epochs': 900,
    'learning_rate': 6e-4,
    'weight_decay': 5e-3,
    'betas': (0.9, 0.999), 
    'eps': 1e-08
}
MLPparametersGDE = {
    'n_layers':2,
    'layer_size_factor':[1, 50], 
    'dropout':[0.3, 0.15],
    'batch_size': 128,
    'num_epochs': 900,
    'learning_rate': 6e-4,
    'weight_decay': 5e-3,
    'betas': (0.9, 0.999), 
    'eps': 1e-08
}
#print(GCNparameters['M'])

# %%
IM = Integrated_Model(GCNparameters, GDEparameters, MLPparametersGCN, MLPparametersGDE, dm, create_DAD(Araw))
# Out:
# 100%|██████████| 6/6 [00:00<00:00, 61.39it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# ----------Training GCN-----------
# device set to cpu
# Epoch: 1   Batch: 6 of size 256   Train loss: 388.9702453613281   Valid loss: 388.10623168945319
# Epoch: 2   Batch: 5 of size 256   Train loss: 384.7411804199219   Valid loss: 384.11914062582031
# 100%|██████████| 6/6 [00:00<00:00, 61.39it/s]
# 100%|██████████| 6/6 [00:00<00:00, 61.39it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# Epoch: 2   Batch: 6 of size 256   Train loss: 383.9039611816406   Valid loss: 383.34454345703125
# Epoch: 3   Batch: 6 of size 256   Train loss: 380.74786376953125   Valid loss: 380.57092285156255
# Epoch: 4   Batch: 5 of size 256   Train loss: 378.4443664550781   Valid loss: 379.075256347656255
# 100%|██████████| 6/6 [00:00<00:00, 64.00it/s]
# 100%|██████████| 6/6 [00:00<00:00, 62.02it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
# Epoch: 4   Batch: 6 of size 256   Train loss: 377.7657470703125   Valid loss: 378.5683898925781
# Epoch: 5   Batch: 6 of size 256   Train loss: 376.7219543457031   Valid loss: 378.21810913085945
# ----------Training Ends-----------
# ----------Training GDE-----------
# device set to cpu
#   9%|▉         | 1/11 [00:00<00:05,  1.94it/s]
# Epoch: 1   Batch: 1 of size 128   Train loss: 393.7986145019531   Valid loss: 392.4302978515625
#  18%|█▊        | 2/11 [00:01<00:04,  1.93it/s]
# Epoch: 1   Batch: 2 of size 128   Train loss: 392.2730712890625   Valid loss: 391.23272705078125
#  27%|██▋       | 3/11 [00:01<00:04,  1.92it/s]
# Epoch: 1   Batch: 3 of size 128   Train loss: 390.92449951171875   Valid loss: 389.93682861328125
#  36%|███▋      | 4/11 [00:02<00:03,  1.92it/s]
# Epoch: 1   Batch: 4 of size 128   Train loss: 389.82720947265625   Valid loss: 388.850341796875
#  45%|████▌     | 5/11 [00:02<00:03,  1.92it/s]
# Epoch: 1   Batch: 5 of size 128   Train loss: 388.5603942871094   Valid loss: 387.75927734375
#  55%|█████▍    | 6/11 [00:03<00:02,  1.92it/s]
# Epoch: 1   Batch: 6 of size 128   Train loss: 387.4100341796875   Valid loss: 386.8428955078125
#  64%|██████▎   | 7/11 [00:03<00:02,  1.90it/s]
# Epoch: 1   Batch: 7 of size 128   Train loss: 386.38226318359375   Valid loss: 385.7080078125
#  73%|███████▎  | 8/11 [00:04<00:01,  1.90it/s]
# Epoch: 1   Batch: 8 of size 128   Train loss: 385.31915283203125   Valid loss: 384.93426513671875
#  82%|████████▏ | 9/11 [00:04<00:01,  1.91it/s]
# Epoch: 1   Batch: 9 of size 128   Train loss: 384.2952880859375   Valid loss: 384.1579284667969
#  91%|█████████ | 10/11 [00:05<00:00,  1.91it/s]
# Epoch: 1   Batch: 10 of size 128   Train loss: 383.427490234375   Valid loss: 383.4246826171875
# 100%|██████████| 11/11 [00:05<00:00,  1.92it/s]
# Epoch: 1   Batch: 11 of size 128   Train loss: 382.3099060058594   Valid loss: 382.9929504394531
# ----------Training Ends-----------
# Average Ictal and Non-Ictal Simularity Matrix for GCN
# Average ictal
# Average Non-Ictal
# Average Ictal and Non-Ictal Simularity Matrix for GDE
# Average ictal
# Average Non-Ictal
# Sample Ictal and Non-Ictal Simularity Matrix for GCN
# sample ictal
# sample Non-Ictal
# Sample Ictal and Non-Ictal Simularity Matrix for GDE
# sample ictal
# sample Non-Ictal
# ----------Training MLP-----------
# 0.603 ----------saved-----------
# 0.678 ----------saved-----------
# 0.73 ----------saved-----------
# 0.748 ----------saved-----------
# 0.762 ----------saved-----------
# 0.772 ----------saved-----------
# 0.78 ----------saved-----------
# 0.788 ----------saved-----------
# 0.795 ----------saved-----------
# 0.801 ----------saved-----------
# 0.808 ----------saved-----------
# 0.812 ----------saved-----------
# 0.815 ----------saved-----------
# 0.819 ----------saved-----------
# 0.821 ----------saved-----------
# 0.821 ----------saved-----------
# 0.822 ----------saved-----------
# 0.822 ----------saved-----------
# 0.823 ----------saved-----------
# 0.823 ----------saved-----------
# 0.823 ----------saved-----------
# ----------------------------------
# 0.623 ----------saved-----------
# 0.673 ----------saved-----------
# 0.701 ----------saved-----------
# 0.717 ----------saved-----------
# 0.724 ----------saved-----------
# 0.727 ----------saved-----------
# 0.731 ----------saved-----------
# 0.735 ----------saved-----------
# 0.739 ----------saved-----------
# 0.744 ----------saved-----------
# 0.749 ----------saved-----------
# 0.757 ----------saved-----------
# 0.765 ----------saved-----------
# 0.772 ----------saved-----------
# 0.777 ----------saved-----------
# 0.782 ----------saved-----------
# 0.785 ----------saved-----------
# 0.787 ----------saved-----------
# 0.789 ----------saved-----------
# 0.79 ----------saved-----------
# 0.792 ----------saved-----------
# 0.794 ----------saved-----------
# 0.796 ----------saved-----------
# 0.796 ----------saved-----------
# 0.797 ----------saved-----------
# 0.797 ----------saved-----------
# 0.798 ----------saved-----------
# 0.799 ----------saved-----------
# C:\Users\caixu\anaconda3\lib\site-packages\sklearn\metrics\_ranking.py:811: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn("No positive samples in y_true, "
# ----------Training Ends-----------

# %%
IM.print_accuracy(dm, Araw, device_name = 'cpu')
# Out:
# GCN accuracy:
# device set to cuda
# threshold: 0.05  validation loss: 0.3338 F1 accuracy 0.336 Precision accuracy 0.206 Recall accuracy 0.902 AUC accuracy: 0.822
# device set to cuda
# threshold: 0.1  validation loss: 0.3338 F1 accuracy 0.465 Precision accuracy 0.363 Recall accuracy 0.644 AUC accuracy: 0.822
# device set to cuda
# threshold: 0.15  validation loss: 0.3338 F1 accuracy 0.503 Precision accuracy 0.61 Recall accuracy 0.428 AUC accuracy: 0.822
# device set to cuda
# threshold: 0.2  validation loss: 0.3338 F1 accuracy 0.369 Precision accuracy 0.77 Recall accuracy 0.242 AUC accuracy: 0.822
# device set to cuda
# threshold: 0.25  validation loss: 0.3338 F1 accuracy 0.148 Precision accuracy 0.727 Recall accuracy 0.082 AUC accuracy: 0.822
# device set to cuda
# threshold: 0.3  validation loss: 0.3338 F1 accuracy 0.096 Precision accuracy 0.714 Recall accuracy 0.052 AUC accuracy: 0.822
# device set to cuda
# threshold: 0.35  validation loss: 0.3338 F1 accuracy 0.05 Precision accuracy 0.714 Recall accuracy 0.026 AUC accuracy: 0.822
# device set to cuda
# threshold: 0.4  validation loss: 0.3338 F1 accuracy 0.02 Precision accuracy 0.667 Recall accuracy 0.01 AUC accuracy: 0.822
# device set to cuda
# threshold: 0.45  validation loss: 0.3338 F1 accuracy 0.01 Precision accuracy 1.0 Recall accuracy 0.005 AUC accuracy: 0.822
# device set to cuda
# threshold: 0.5  validation loss: 0.3338 F1 accuracy 0.01 Precision accuracy 1.0 Recall accuracy 0.005 AUC accuracy: 0.822
# device set to cuda
# threshold: 0.55  validation loss: 0.3338 F1 accuracy 0.01 Precision accuracy 1.0 Recall accuracy 0.005 AUC accuracy: 0.822
# device set to cuda
# threshold: 0.6  validation loss: 0.3338 F1 accuracy 0.0 Precision accuracy 0.0 Recall accuracy 0.0 AUC accuracy: 0.822
# device set to cuda
# threshold: 0.65  validation loss: 0.3338 F1 accuracy 0.0 Precision accuracy 0.0 Recall accuracy 0.0 AUC accuracy: 0.822
# device set to cuda
# threshold: 0.7  validation loss: 0.3338 F1 accuracy 0.0 Precision accuracy 0.0 Recall accuracy 0.0 AUC accuracy: 0.822
# device set to cuda
# threshold: 0.75  validation loss: 0.3338 F1 accuracy 0.0 Precision accuracy 0.0 Recall accuracy 0.0 AUC accuracy: 0.822
# device set to cuda
# threshold: 0.8  validation loss: 0.3338 F1 accuracy 0.0 Precision accuracy 0.0 Recall accuracy 0.0 AUC accuracy: 0.822
# device set to cuda
# threshold: 0.85  validation loss: 0.3338 F1 accuracy 0.0 Precision accuracy 0.0 Recall accuracy 0.0 AUC accuracy: 0.822
# device set to cuda
# threshold: 0.9  validation loss: 0.3338 F1 accuracy 0.0 Precision accuracy 0.0 Recall accuracy 0.0 AUC accuracy: 0.822
# device set to cuda
# threshold: 0.95  validation loss: 0.3338 F1 accuracy 0.0 Precision accuracy 0.0 Recall accuracy 0.0 AUC accuracy: 0.822
# device set to cuda
# GDE accuracy:
# device set to cuda
# threshold: 0.05  validation loss: 0.3467 F1 accuracy 0.259 Precision accuracy 0.149 Recall accuracy 0.974 AUC accuracy: 0.799
# device set to cuda
# threshold: 0.1  validation loss: 0.3467 F1 accuracy 0.393 Precision accuracy 0.278 Recall accuracy 0.675 AUC accuracy: 0.799
# device set to cuda
# threshold: 0.15  validation loss: 0.3467 F1 accuracy 0.431 Precision accuracy 0.589 Recall accuracy 0.34 AUC accuracy: 0.799
# device set to cuda
# threshold: 0.2  validation loss: 0.3467 F1 accuracy 0.245 Precision accuracy 0.8 Recall accuracy 0.144 AUC accuracy: 0.799
# device set to cuda
# threshold: 0.25  validation loss: 0.3467 F1 accuracy 0.069 Precision accuracy 0.7 Recall accuracy 0.036 AUC accuracy: 0.799
# device set to cuda
# threshold: 0.3  validation loss: 0.3467 F1 accuracy 0.01 Precision accuracy 0.5 Recall accuracy 0.005 AUC accuracy: 0.799
# device set to cuda
# threshold: 0.35  validation loss: 0.3467 F1 accuracy 0.0 Precision accuracy 0.0 Recall accuracy 0.0 AUC accuracy: 0.799
# device set to cuda
# threshold: 0.4  validation loss: 0.3467 F1 accuracy 0.0 Precision accuracy 0.0 Recall accuracy 0.0 AUC accuracy: 0.799
# device set to cuda
# threshold: 0.45  validation loss: 0.3467 F1 accuracy 0.0 Precision accuracy 0.0 Recall accuracy 0.0 AUC accuracy: 0.799
# device set to cuda
# threshold: 0.5  validation loss: 0.3467 F1 accuracy 0.0 Precision accuracy 0.0 Recall accuracy 0.0 AUC accuracy: 0.799
# device set to cuda
# threshold: 0.55  validation loss: 0.3467 F1 accuracy 0.0 Precision accuracy 0.0 Recall accuracy 0.0 AUC accuracy: 0.799
# device set to cuda
# C:\Users\caixu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\caixu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# threshold: 0.6  validation loss: 0.3467 F1 accuracy 0.0 Precision accuracy 0.0 Recall accuracy 0.0 AUC accuracy: 0.799
# device set to cuda
# threshold: 0.65  validation loss: 0.3467 F1 accuracy 0.0 Precision accuracy 0.0 Recall accuracy 0.0 AUC accuracy: 0.799
# device set to cuda
# threshold: 0.7  validation loss: 0.3467 F1 accuracy 0.0 Precision accuracy 0.0 Recall accuracy 0.0 AUC accuracy: 0.799
# device set to cuda
# threshold: 0.75  validation loss: 0.3467 F1 accuracy 0.0 Precision accuracy 0.0 Recall accuracy 0.0 AUC accuracy: 0.799
# device set to cuda
# threshold: 0.8  validation loss: 0.3467 F1 accuracy 0.0 Precision accuracy 0.0 Recall accuracy 0.0 AUC accuracy: 0.799
# device set to cuda
# threshold: 0.85  validation loss: 0.3467 F1 accuracy 0.0 Precision accuracy 0.0 Recall accuracy 0.0 AUC accuracy: 0.799
# device set to cuda
# threshold: 0.9  validation loss: 0.3467 F1 accuracy 0.0 Precision accuracy 0.0 Recall accuracy 0.0 AUC accuracy: 0.799
# device set to cuda
# threshold: 0.95  validation loss: 0.3467 F1 accuracy 0.0 Precision accuracy 0.0 Recall accuracy 0.0 AUC accuracy: 0.799
# device set to cuda

# %%
records = IM.MLPcheckpointGCN['record']
val_loss = records['val_loses'][:100]
val_auc = records['val_auc'][:100]
train_loss = records['train_loss'][:100]
train_auc = records['train_auc'][:100]
import matplotlib.pyplot as plt
plt.plot(range(len(val_loss)), val_loss)
plt.plot(range(len(val_auc)), val_auc)
plt.plot(range(len(val_loss)), train_loss)
plt.plot(range(len(val_auc)), train_auc)
plt.show()
