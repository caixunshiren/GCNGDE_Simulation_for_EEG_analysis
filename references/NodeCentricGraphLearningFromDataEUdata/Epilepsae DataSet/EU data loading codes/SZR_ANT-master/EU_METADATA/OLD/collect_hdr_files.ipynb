# %% [markdown]
# # Code for copying all EU iEEG header files into EU_METADATA subdirectory

# %%
import pandas as pd
import os
from pathlib import Path
from shutil import copyfile

# %%
sub='1096'
sub='958'
eu_root='/media/dgroppe/ValianteLabEuData/EU/'
# Collect possible subject directories
inv_dirs=list()
for a in range(1,4):
    if a==1:
        inv_dirs.append(os.path.join(eu_root,'inv'))
    else:
        inv_dirs.append(os.path.join(eu_root,'inv'+str(a)))
print(inv_dirs)
# Out:
# ['/media/dgroppe/ValianteLabEuData/EU/inv', '/media/dgroppe/ValianteLabEuData/EU/inv2', '/media/dgroppe/ValianteLabEuData/EU/inv3']

# %%
# Find which inv* directory the subject is in
use_dir=[]
for sub_dir in inv_dirs:
    full_dir=Path(os.path.join(sub_dir,'pat_FR_'+str(sub)))
    if full_dir.is_dir():
        use_dir=full_dir
if use_dir==[]:
    print('Error inv* subdirectory not found for %d' % sub)
else:
    print(use_dir)
# Out:
# /media/dgroppe/ValianteLabEuData/EU/inv/pat_FR_958

# %%
# Find all data subdirectories for this sub

# get adm subdir
for f in os.listdir(use_dir):
    if f.startswith('adm_'):
        adm_dir=os.path.join(use_dir,f)

# get all rec subdirs
rec_dirs=list()
for f in os.listdir(adm_dir):
    if f.startswith('rec_'):
        rec_dirs.append(os.path.join(adm_dir,f))
# Out:
# ['/media/dgroppe/ValianteLabEuData/EU/inv/pat_FR_958/adm_958102/rec_95800102', '/media/dgroppe/ValianteLabEuData/EU/inv/pat_FR_958/adm_958102/rec_95801102', '/media/dgroppe/ValianteLabEuData/EU/inv/pat_FR_958/adm_958102/rec_95802102']

# %%
# Destination directory
dest_dir=os.path.join('/home/dgroppe/GIT/SZR_ANT/EU_METADATA/IEEG_HEADERS/',str(sub)+'_headers')
if Path(dest_dir).is_dir():
    print('Warning: %s exists' % dest_dir)
else:
    os.mkdir(dest_dir)

# Loop over rec_dirs and cp over and header files 
for d in rec_dirs:
    cmnd='cp ' + os.path.join(d,'*.head') + ' ' + dest_dir
    os.system(cmnd)
    print(cmnd)
    #copyfile(os.path.join(d,'*.head'), dest_dir)
# Out:
# Warning: /home/dgroppe/GIT/SZR_ANT/EU_METADATA/IEEG_HEADERS/958_headers exists
# cp /media/dgroppe/ValianteLabEuData/EU/inv/pat_FR_958/adm_958102/rec_95800102/*.head /home/dgroppe/GIT/SZR_ANT/EU_METADATA/IEEG_HEADERS/958_headers
# cp /media/dgroppe/ValianteLabEuData/EU/inv/pat_FR_958/adm_958102/rec_95801102/*.head /home/dgroppe/GIT/SZR_ANT/EU_METADATA/IEEG_HEADERS/958_headers
# cp /media/dgroppe/ValianteLabEuData/EU/inv/pat_FR_958/adm_958102/rec_95802102/*.head /home/dgroppe/GIT/SZR_ANT/EU_METADATA/IEEG_HEADERS/958_headers

# %%
sub='1096'
metadata_dir='/Users/davidgroppe/PycharmProjects/SZR_ANT/EU_METADATA/ELEC_HTML/'
html_fname=os.path.join(metadata_dir,'elecs_'+sub+'.html')
print('Attempting to read %s' % html_fname)
htable=pd.read_html(html_fname)
# Out:
# Attempting to read /Users/davidgroppe/PycharmProjects/SZR_ANT/EU_METADATA/ELEC_HTML/elecs_1096.html

# %%
len(htable)
# Out:
# 1

# %%
htable[0]
# Out:
#                      electrode_array    name moniker artifact focus_relat  \
# 0          32  109600102: G_ (grid )     GC5   (GC5)      NaN           e
# 1                                GB4   (GB4)     NaN        e      AdTech
# 2                                GB5   (GB5)     NaN        e      AdTech
# 3                                GB6   (GB6)     NaN        e      AdTech
# 4                                GB8   (GB8)     NaN        e      AdTech
# 5                                GC1   (GC1)     NaN        e      AdTech
# 6                                GC3   (GC3)     NaN        e      AdTech
# 7                                GC4   (GC4)     NaN        e      AdTech
# 8                                GC7   (GC7)     NaN        e      AdTech
# 9                                GD3   (GD3)     NaN        e      AdTech
# 10                               GC8   (GC8)     NaN        e      AdTech
# 11                               GD1   (GD1)     NaN        e      AdTech
# 12                               GD5   (GD5)     NaN        e      AdTech
# 13                               GD7   (GD7)     NaN        e      AdTech
# 14                               GD8   (GD8)     NaN        e      AdTech
# 15                               GA1   (GA1)     NaN        e      AdTech
# 16                               GB2   (GB2)     NaN        e      AdTech
# 17                               GA5   (GA5)     NaN        e      AdTech
# 18                               GA6   (GA6)     NaN        e      AdTech
# 19                               GA8   (GA8)     NaN        e      AdTech
# 20                               GB1   (GB1)     NaN        e      AdTech
# 21                               GA2   (GA2)     NaN        e      AdTech
# 22                               GA3   (GA3)     NaN        e      AdTech
# 23                               GA4   (GA4)     NaN        e      AdTech
# 24                               GA7   (GA7)     NaN        e      AdTech
# 25                               GB3   (GB3)     NaN        e      AdTech
# 26                               GB7   (GB7)     NaN        e      AdTech
# 27                               GC2   (GC2)     NaN        e      AdTech
# 28                               GC6   (GC6)     NaN        e      AdTech
# 29                               GD2   (GD2)     NaN        e      AdTech
# ..                               ...     ...     ...      ...         ...
# 71                              HRC2  (HRC2)     NaN        l      AdTech
# 72                              HRC3  (HRC3)     NaN        l      AdTech
# 73                              HRC4  (HRC4)     NaN        l      AdTech
# 74                              HRC5  (HRC5)     NaN        l      AdTech
# 75       2  109602102: 10-10 (surf )     FT9    (T1)      NaN           l
# 76                              FT10    (T2)     NaN        l         NaN
# 77      19  109625102: 10-20 (surf )      FZ    (FZ)      NaN           l
# 78                               FP2   (FP2)     NaN        l         NaN
# 79                                F3    (F3)     NaN        l         NaN
# 80                                F4    (F4)     NaN        l         NaN
# 81                                C3    (C3)     NaN        l         NaN
# 82                                C4    (C4)     NaN        l         NaN
# 83                                P3    (P3)     NaN        l         NaN
# 84                                P4    (P4)     NaN        l         NaN
# 85                                O1    (O1)     NaN        l         NaN
# 86                                O2    (O2)     NaN        l         NaN
# 87                                F7    (F7)     NaN        l         NaN
# 88                                F8    (F8)     NaN        l         NaN
# 89                                T7    (T3)     NaN        l         NaN
# 90                                T8    (T4)     NaN        l         NaN
# 91                                P7    (T5)     NaN        l         NaN
# 92                               FP1   (FP1)     NaN        l         NaN
# 93                                P8    (T6)     NaN        l         NaN
# 94                                CZ    (CZ)     NaN        l         NaN
# 95                                PZ    (PZ)     NaN        l         NaN
# 96          1  109629102: ECG (ecg )     ECG   (ECG)      NaN         NaN
# 97          2  109630102: EOG (eog )    EOG1  (EOG1)      NaN         NaN
# 98                              EOG2  (EOG2)     NaN      NaN         NaN
# 99          1  109631102: EMG (emg )     EMG   (EMG)      NaN         NaN
# 100  14 electrode_array(s) retrieved     NaN     NaN      NaN         NaN
#
#     supplier      x      y                     z                commentary  \
# 0     AdTech  155.0  110.0                  69.0                       NaN
# 1      153.0  126.0   66.0                   NaN                   12: GB4
# 2      154.0  120.0   76.0                   NaN                   13: GB5
# 3      154.0  112.0   87.0                   NaN                   14: GB6
# 4      151.0   98.0  107.0                   NaN                   16: GB8
# 5      136.0  136.0   24.0                   NaN                   17: GC1
# 6      152.0  123.0   48.0                   NaN                   19: GC3
# 7      155.0  117.0   58.0                   NaN                   20: GC4
# 8      152.0   95.0   89.0                   NaN                   23: GC7
# 9      149.0  114.0   43.0                   NaN                   27: GD3
# 10     152.0   88.0   99.0                   NaN                   24: GC8
# 11     136.0  124.0   26.0                   NaN                   25: GD1
# 12     157.0   99.0   64.0                   NaN                   29: GD5
# 13     154.0   85.0   81.0                   NaN                   31: GD7
# 14     153.0   80.0   91.0                   NaN                   32: GD8
# 15     140.0  156.0   43.0                   NaN                    1: GA1
# 16     145.0  140.0   45.0                   NaN                   10: GB2
# 17     153.0  129.0   82.0                   NaN                    5: GA5
# 18     153.0  121.0   93.0                   NaN                    6: GA6
# 19     151.0  108.0  111.0                   NaN                    8: GA8
# 20     139.0  146.0   36.0                   NaN                    9: GB1
# 21     143.0  149.0   53.0                   NaN                    2: GA2
# 22     148.0  144.0   62.0                   NaN                    3: GA3
# 23     151.0  136.0   73.0                   NaN                    4: GA4
# 24     153.0  114.0  103.0                   NaN                    7: GA7
# 25     150.0  134.0   56.0                   NaN                   11: GB3
# 26     154.0  105.0   97.0                   NaN                   15: GB7
# 27     144.0  129.0   38.0                   NaN                   18: GC2
# 28     155.0  102.0   80.0                   NaN                   22: GC6
# 29     143.0  119.0   33.0                   NaN                   26: GD2
# ..       ...    ...    ...                   ...                       ...
# 71      56.0  100.0   57.0                   NaN                  69: HRC2
# 72      48.0   97.0   57.0                   NaN                  70: HRC3
# 73      30.0   89.0   58.0                   NaN                  71: HRC4
# 74      22.0   83.0   59.0                   NaN                  72: HRC5
# 75       NaN      -      -                     -                       NaN
# 76         -      -      -                   NaN                    97: T2
# 77       NaN      -      -                     -                       NaN
# 78         -      -      -                   NaN                   78: FP2
# 79         -      -      -                   NaN                    79: F3
# 80         -      -      -                   NaN                    80: F4
# 81         -      -      -                   NaN                    81: C3
# 82         -      -      -                   NaN                    82: C4
# 83         -      -      -                   NaN                    83: P3
# 84         -      -      -                   NaN                    84: P4
# 85         -      -      -                   NaN                    85: O1
# 86         -      -      -                   NaN                    86: O2
# 87         -      -      -                   NaN                    87: F7
# 88         -      -      -                   NaN                    88: F8
# 89         -      -      -                   NaN                    89: T3
# 90         -      -      -                   NaN                    90: T4
# 91         -      -      -                   NaN                    91: T5
# 92         -      -      -                   NaN                   77: FP1
# 93         -      -      -                   NaN                    92: T6
# 94         -      -      -                   NaN                    94: CZ
# 95         -      -      -                   NaN                    95: PZ
# 96       NaN      -      -                     -             ecg electrode
# 97       NaN      -      -                     -      eog electrode (eyes)
# 98         -      -      -  eog electrode (eyes)                  99: EOG2
# 99       NaN      -      -                     -  emg electrode (muscular)
# 100      NaN    NaN    NaN                   NaN                       NaN
#
#     ch. in rec 1
# 0        21: GC5
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# 5            NaN
# 6            NaN
# 7            NaN
# 8            NaN
# 9            NaN
# 10           NaN
# 11           NaN
# 12           NaN
# 13           NaN
# 14           NaN
# 15           NaN
# 16           NaN
# 17           NaN
# 18           NaN
# 19           NaN
# 20           NaN
# 21           NaN
# 22           NaN
# 23           NaN
# 24           NaN
# 25           NaN
# 26           NaN
# 27           NaN
# 28           NaN
# 29           NaN
# ..           ...
# 71           NaN
# 72           NaN
# 73           NaN
# 74           NaN
# 75        96: T1
# 76           NaN
# 77        93: FZ
# 78           NaN
# 79           NaN
# 80           NaN
# 81           NaN
# 82           NaN
# 83           NaN
# 84           NaN
# 85           NaN
# 86           NaN
# 87           NaN
# 88           NaN
# 89           NaN
# 90           NaN
# 91           NaN
# 92           NaN
# 93           NaN
# 94           NaN
# 95           NaN
# 96       62: ECG
# 97      98: EOG1
# 98           NaN
# 99      100: EMG
# 100          NaN
#
# [101 rows x 11 columns]
