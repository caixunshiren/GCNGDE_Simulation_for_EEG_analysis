# %%
# %reload_ext autoreload
# %autoreload 2
#Custom Files
from DataManager import dataManager
from DataManagerUtil import *
import GCN as GCN
import GCNutil as GCNutil
import GDE as GDE
import GDEutil as GDEutil
import GDEsolvers as GDEsolvers
import MLP as MLP
from Full_model import Integrated_Model

#Standard Libraries
# Torch
import torch
import torch.autograd
import torch.nn as nn
import torch.nn.functional as F
#Numpy
import numpy as np

# %%
#Loading everything from the dataset
filepath = 'datasets\pat_FR_273.mat' #264 253 620 273
variables = load_patient_data(filepath, verbose = True)
# Out:
# name: X_test
# shape: (640, 35, 2649)
# -----------------------
# name: X_train
# shape: (640, 35, 2564)
# -----------------------
# name: clip_sizes_test
# shape: (2, 102)
# -----------------------
# name: clip_sizes_train
# shape: (2, 101)
# -----------------------
# name: conv_sizes
# shape: (1, 1)
# -----------------------
# name: n_pre_szr
# shape: (1, 1)
# -----------------------
# name: sel_win_nums_test
# shape: (1, 2649)
# -----------------------
# name: sel_win_nums_train
# shape: (1, 2564)
# -----------------------
# name: soz_ch_ids
# shape: (7, 1)
# -----------------------
# name: stride_sec
# shape: (1, 1)
# -----------------------
# name: window_size_sec
# shape: (1, 1)
# -----------------------
# name: y_test
# shape: (1, 2649)
# -----------------------
# name: y_train
# shape: (1, 2564)
# -----------------------
# print sample EGG signal from one node:

# %%
dm = dataManager(variables["X_train"],variables["X_test"],variables["y_train"],variables["y_test"],10**(-4))

# %%
#reduce redundant nodes
#from DataManager import get_label_variance as glv
#print(glv(dm.X_train, dm.Y_train))
#print(np.argsort(glv(dm.X_train, dm.Y_train)))
print(dm)
#dm.apply_dvariance_filter(30)
#dm.mean_pooling_1d(size = 15, stride = 13, padding = 0)
print(dm)
# Out:
# X_train: shape of(2562, 35, 640)
# X_test: shape of(2649, 35, 640)
# Y_train: shape of(2562, 1)
# Y_test: shape of(2649, 1)
# A_train: shape of(35, 35)
# A_test: shape of(35, 35)
# P_avg_train: shape of(35, 35)
# P_avg_test: shape of(35, 35)
# X_train: shape of(2562, 35, 49)
# X_test: shape of(2649, 35, 49)
# Y_train: shape of(2562, 1)
# Y_test: shape of(2649, 1)
# A_train: shape of(35, 35)
# A_test: shape of(35, 35)
# P_avg_train: shape of(35, 35)
# P_avg_test: shape of(35, 35)

# %%
show_heat_map(dm.P_avg_train)

# %%
n = 8.5*10**-4
dm.re_threshold(n)
show_heat_map(dm.A_train)
show_heat_map(create_DAD(dm.A_train))
Araw = dm.A_train

# %%
GCNparameters = {
    'body': dm.X_train.shape[2],
    'M': dm.X_train.shape[0],
    'batch_size': 512,
    'n_layers': 2,
    'num_epochs': 1,
    'learning_rate': 1e-3,
    'weight_decay': 5e-3
}
GDEparameters = {
    'body': dm.X_train.shape[2],
    'solver': GDEsolvers.explicit_RK,
    'solver_params': {
    "t0": 0,
    "t1": 0.25,
    "N": 5,
    "b_tableau": GDEsolvers.EF
     },
    'hidden_layers': 1,
    'M': dm.X_train.shape[0],
    'batch_size': 128,
    'num_epochs': 1,
    'learning_rate': 1e-3,
    'weight_decay': 5e-3
}
MLPparametersGCN = {
    'n_layers':2,
    'layer_size_factor':[1,1], 
    'dropout':[0.3, 0.3],
    'batch_size': 128,
    'num_epochs': 900,
    'learning_rate': 6e-4,
    'weight_decay': 5e-3,
    'betas': (0.9, 0.999), 
    'eps': 1e-08
}
MLPparametersGDE = {
    'n_layers':2,
    'layer_size_factor':[1, 64], 
    'dropout':[0.3, 0.3],
    'batch_size': 128,
    'num_epochs': 900,
    'learning_rate': 6e-4,
    'weight_decay': 5e-3,
    'betas': (0.9, 0.999), 
    'eps': 1e-08
}
#print(GCNparameters['M'])

# %%
IM = Integrated_Model(GCNparameters, GDEparameters, MLPparametersGCN, MLPparametersGDE, dm, Araw)
# Out:
#  17%|█▋        | 1/6 [00:00<00:00,  9.64it/s]
# ----------Training GCN-----------
# device set to cpu
# Epoch: 1   Batch: 1 of size 512   Train loss: 756.8458251953125   Valid loss: 755.8114624023438
#  50%|█████     | 3/6 [00:00<00:00,  9.50it/s]
# Epoch: 1   Batch: 3 of size 512   Train loss: 755.1513061523438   Valid loss: 754.6838378906255
# 100%|██████████| 6/6 [00:00<00:00, 11.37it/s]
#   0%|          | 0/21 [00:00<?, ?it/s]
# Epoch: 1   Batch: 6 of size 512   Train loss: 756.640625   Valid loss: 754.64526367187543164062
# ----------Training Ends-----------
# ----------Training GDE-----------
# device set to cpu
# Epoch:
#  10%|▉         | 2/21 [00:00<00:01, 14.97it/s]
# Epoch: 1   Batch: 3 of size 128   Train loss: 755.4498291015625   Valid loss: 754.7366333007812
#  29%|██▊       | 6/21 [00:00<00:00, 15.43it/s]
# Epoch: 1   Batch: 6 of size 128   Train loss: 754.240478515625   Valid loss: 753.7909545898438
#  48%|████▊     | 10/21 [00:00<00:00, 15.89it/s]
# Epoch: 1   Batch: 10 of size 128   Train loss: 754.5472412109375   Valid loss: 754.2362060546875
#  57%|█████▋    | 12/21 [00:00<00:00, 15.67it/s]
# Epoch: 1   Batch: 13 of size 128   Train loss: 754.9686279296875   Valid loss: 754.1691894531252
#  76%|███████▌  | 16/21 [00:01<00:00, 15.74it/s]
# Epoch: 1   Batch: 16 of size 128   Train loss: 754.09619140625   Valid loss: 753.82678222656255
#  86%|████████▌ | 18/21 [00:01<00:00, 15.65it/s]
# Epoch: 1   Batch: 19 of size 128   Train loss: 753.9324951171875   Valid loss: 753.9164428710938
# 100%|██████████| 21/21 [00:01<00:00, 16.34it/s]
# Epoch: 1   Batch: 21 of size 128   Train loss: 753.3592529296875   Valid loss: 754.1528320312525
# ----------Training Ends-----------
# ----------Training MLP-----------
# 0.481 ----------saved-----------
# 0.664 ----------saved-----------
# 0.682 ----------saved-----------
# 0.69 ----------saved-----------
# 0.701 ----------saved-----------
# 0.719 ----------saved-----------
# 0.719 ----------saved-----------
# 0.72 ----------saved-----------
# 0.721 ----------saved-----------
# 0.733 ----------saved-----------
# 0.74 ----------saved-----------
# 0.742 ----------saved-----------
# 0.743 ----------saved-----------
# 0.743 ----------saved-----------
# 0.744 ----------saved-----------
# 0.207 ----------saved-----------
# 0.278 ----------saved-----------
# 0.343 ----------saved-----------
# 0.388 ----------saved-----------
# 0.468 ----------saved-----------
# 0.507 ----------saved-----------
# 0.517 ----------saved-----------
# 0.557 ----------saved-----------
# 0.613 ----------saved-----------
# 0.652 ----------saved-----------
# 0.668 ----------saved-----------
# 0.683 ----------saved-----------
# 0.689 ----------saved-----------
# 0.691 ----------saved-----------
# 0.705 ----------saved-----------
# 0.712 ----------saved-----------
# 0.719 ----------saved-----------
# 0.72 ----------saved-----------
# 0.723 ----------saved-----------
# 0.725 ----------saved-----------
# 0.726 ----------saved-----------
# 0.729 ----------saved-----------
# 0.738 ----------saved-----------
# 0.738 ----------saved-----------
# 0.739 ----------saved-----------
# 0.739 ----------saved-----------
# 0.742 ----------saved-----------
# 0.746 ----------saved-----------
# 0.748 ----------saved-----------
# 0.749 ----------saved-----------
# 0.749 ----------saved-----------
# 0.751 ----------saved-----------
# 0.76 ----------saved-----------
# 0.762 ----------saved-----------
# 0.765 ----------saved-----------
# 0.769 ----------saved-----------
# 0.772 ----------saved-----------
# 0.772 ----------saved-----------
# 0.774 ----------saved-----------
# 0.779 ----------saved-----------
# 0.78 ----------saved-----------
# 0.783 ----------saved-----------
# 0.787 ----------saved-----------
# ----------Training Ends-----------

# %%
IM.print_accuracy(dm, Araw, device_name = 'cpu')
# Out:
# GCN accuracy:
# device set to cuda
# threshold: 0.05  validation loss: 0.1708 F1 accuracy 0.505 Precision accuracy 0.355 Recall accuracy 0.871 AUC accuracy: 0.919
# device set to cuda
# threshold: 0.1  validation loss: 0.1708 F1 accuracy 0.625 Precision accuracy 0.506 Recall accuracy 0.817 AUC accuracy: 0.919
# device set to cuda
# threshold: 0.15  validation loss: 0.1708 F1 accuracy 0.696 Precision accuracy 0.624 Recall accuracy 0.786 AUC accuracy: 0.919
# device set to cuda
# threshold: 0.2  validation loss: 0.1708 F1 accuracy 0.724 Precision accuracy 0.706 Recall accuracy 0.742 AUC accuracy: 0.919
# device set to cuda
# threshold: 0.25  validation loss: 0.1708 F1 accuracy 0.734 Precision accuracy 0.77 Recall accuracy 0.702 AUC accuracy: 0.919
# device set to cuda
# threshold: 0.3  validation loss: 0.1708 F1 accuracy 0.744 Precision accuracy 0.815 Recall accuracy 0.685 AUC accuracy: 0.919
# device set to cuda
# threshold: 0.35  validation loss: 0.1708 F1 accuracy 0.738 Precision accuracy 0.846 Recall accuracy 0.654 AUC accuracy: 0.919
# device set to cuda
# threshold: 0.4  validation loss: 0.1708 F1 accuracy 0.723 Precision accuracy 0.895 Recall accuracy 0.607 AUC accuracy: 0.919
# device set to cuda
# threshold: 0.45  validation loss: 0.1708 F1 accuracy 0.693 Precision accuracy 0.902 Recall accuracy 0.563 AUC accuracy: 0.919
# device set to cuda
# threshold: 0.5  validation loss: 0.1708 F1 accuracy 0.667 Precision accuracy 0.933 Recall accuracy 0.519 AUC accuracy: 0.919
# device set to cuda
# threshold: 0.55  validation loss: 0.1708 F1 accuracy 0.649 Precision accuracy 0.942 Recall accuracy 0.495 AUC accuracy: 0.919
# device set to cuda
# threshold: 0.6  validation loss: 0.1708 F1 accuracy 0.635 Precision accuracy 0.959 Recall accuracy 0.475 AUC accuracy: 0.919
# device set to cuda
# threshold: 0.65  validation loss: 0.1708 F1 accuracy 0.616 Precision accuracy 0.971 Recall accuracy 0.451 AUC accuracy: 0.919
# device set to cuda
# threshold: 0.7  validation loss: 0.1708 F1 accuracy 0.6 Precision accuracy 0.992 Recall accuracy 0.431 AUC accuracy: 0.919
# device set to cuda
# threshold: 0.75  validation loss: 0.1708 F1 accuracy 0.571 Precision accuracy 1.0 Recall accuracy 0.4 AUC accuracy: 0.919
# device set to cuda
# threshold: 0.8  validation loss: 0.1708 F1 accuracy 0.529 Precision accuracy 1.0 Recall accuracy 0.359 AUC accuracy: 0.919
# device set to cuda
# threshold: 0.85  validation loss: 0.1708 F1 accuracy 0.487 Precision accuracy 1.0 Recall accuracy 0.322 AUC accuracy: 0.919
# device set to cuda
# threshold: 0.9  validation loss: 0.1708 F1 accuracy 0.422 Precision accuracy 1.0 Recall accuracy 0.268 AUC accuracy: 0.919
# device set to cuda
# threshold: 0.95  validation loss: 0.1708 F1 accuracy 0.314 Precision accuracy 1.0 Recall accuracy 0.186 AUC accuracy: 0.919
# GDE accuracy:
# device set to cuda
# threshold: 0.05  validation loss: 0.1555 F1 accuracy 0.431 Precision accuracy 0.282 Recall accuracy 0.912 AUC accuracy: 0.929
# device set to cuda
# threshold: 0.1  validation loss: 0.1555 F1 accuracy 0.579 Precision accuracy 0.433 Recall accuracy 0.871 AUC accuracy: 0.929
# device set to cuda
# threshold: 0.15  validation loss: 0.1555 F1 accuracy 0.668 Precision accuracy 0.555 Recall accuracy 0.841 AUC accuracy: 0.929
# device set to cuda
# threshold: 0.2  validation loss: 0.1555 F1 accuracy 0.715 Precision accuracy 0.636 Recall accuracy 0.817 AUC accuracy: 0.929
# device set to cuda
# threshold: 0.25  validation loss: 0.1555 F1 accuracy 0.746 Precision accuracy 0.706 Recall accuracy 0.79 AUC accuracy: 0.929
# device set to cuda
# threshold: 0.3  validation loss: 0.1555 F1 accuracy 0.787 Precision accuracy 0.805 Recall accuracy 0.769 AUC accuracy: 0.929
# device set to cuda
# threshold: 0.35  validation loss: 0.1555 F1 accuracy 0.768 Precision accuracy 0.833 Recall accuracy 0.712 AUC accuracy: 0.929
# device set to cuda
# threshold: 0.4  validation loss: 0.1555 F1 accuracy 0.769 Precision accuracy 0.871 Recall accuracy 0.688 AUC accuracy: 0.929
# device set to cuda
# threshold: 0.45  validation loss: 0.1555 F1 accuracy 0.762 Precision accuracy 0.887 Recall accuracy 0.668 AUC accuracy: 0.929
# device set to cuda
# threshold: 0.5  validation loss: 0.1555 F1 accuracy 0.743 Precision accuracy 0.911 Recall accuracy 0.627 AUC accuracy: 0.929
# device set to cuda
# threshold: 0.55  validation loss: 0.1555 F1 accuracy 0.715 Precision accuracy 0.934 Recall accuracy 0.58 AUC accuracy: 0.929
# device set to cuda
# threshold: 0.6  validation loss: 0.1555 F1 accuracy 0.688 Precision accuracy 0.931 Recall accuracy 0.546 AUC accuracy: 0.929
# device set to cuda
# threshold: 0.65  validation loss: 0.1555 F1 accuracy 0.667 Precision accuracy 0.944 Recall accuracy 0.515 AUC accuracy: 0.929
# device set to cuda
# threshold: 0.7  validation loss: 0.1555 F1 accuracy 0.655 Precision accuracy 0.955 Recall accuracy 0.498 AUC accuracy: 0.929
# device set to cuda
# threshold: 0.75  validation loss: 0.1555 F1 accuracy 0.63 Precision accuracy 0.965 Recall accuracy 0.468 AUC accuracy: 0.929
# device set to cuda
# threshold: 0.8  validation loss: 0.1555 F1 accuracy 0.61 Precision accuracy 0.992 Recall accuracy 0.441 AUC accuracy: 0.929
# device set to cuda
# threshold: 0.85  validation loss: 0.1555 F1 accuracy 0.568 Precision accuracy 1.0 Recall accuracy 0.397 AUC accuracy: 0.929
# device set to cuda
# threshold: 0.9  validation loss: 0.1555 F1 accuracy 0.472 Precision accuracy 1.0 Recall accuracy 0.308 AUC accuracy: 0.929
# device set to cuda
# threshold: 0.95  validation loss: 0.1555 F1 accuracy 0.305 Precision accuracy 1.0 Recall accuracy 0.18 AUC accuracy: 0.929
