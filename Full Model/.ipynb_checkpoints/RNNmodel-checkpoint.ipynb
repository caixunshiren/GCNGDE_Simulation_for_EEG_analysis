# %%
# %reload_ext autoreload
# %autoreload 2
#Custom Files
from DataManager import dataManager
from DataManagerUtil import *
import GCN as GCN
import GCNutil as GCNutil
import GDE as GDE
import GDEutil as GDEutil
import GDEsolvers as GDEsolvers
import MLP as MLP
from Full_model import Integrated_Model, Integrated_Model_RNN
import RNN as RNN

#Standard Libraries
# Torch
import torch
import torch.autograd
import torch.nn as nn
import torch.nn.functional as F
#Numpy
import numpy as np

# %%
#Loading everything from the dataset
filepath = 'datasets\pat_FR_620.mat' #264 253 620 273
variables = load_patient_data(filepath, verbose = True)
# Out:
# name: X_test
# shape: (640, 31, 1518)
# -----------------------
# name: X_train
# shape: (640, 31, 1395)
# -----------------------
# name: clip_sizes_test
# shape: (2, 129)
# -----------------------
# name: clip_sizes_train
# shape: (2, 127)
# -----------------------
# name: conv_sizes
# shape: (1, 1)
# -----------------------
# name: n_pre_szr
# shape: (1, 1)
# -----------------------
# name: sel_win_nums_test
# shape: (1, 1518)
# -----------------------
# name: sel_win_nums_train
# shape: (1, 1395)
# -----------------------
# name: soz_ch_ids
# shape: (5, 1)
# -----------------------
# name: stride_sec
# shape: (1, 1)
# -----------------------
# name: window_size_sec
# shape: (1, 1)
# -----------------------
# name: y_test
# shape: (1, 1518)
# -----------------------
# name: y_train
# shape: (1, 1395)
# -----------------------
# print sample EGG signal from one node:

# %%
dm = dataManager(variables["X_train"],variables["X_test"],variables["y_train"],variables["y_test"],10**(-4))
# Out:
# --------data manager successfully initialized--------

# %%
#reduce redundant nodes
#from DataManager import get_label_variance as glv
#print(glv(dm.X_train, dm.Y_train))
#print(np.argsort(glv(dm.X_train, dm.Y_train)))
print(dm)
dm.apply_dvariance_filter(28)
dm.mean_pooling_1d(size = 24, stride = 20, padding = 0)
print(dm)
# Out:
# X_train: shape of(1387, 31, 640)
# X_test: shape of(1487, 31, 640)
# Y_train: shape of(1387, 1)
# Y_test: shape of(1487, 1)
# A_train: shape of(31, 31)
# A_test: shape of(31, 31)
# P_avg_train: shape of(31, 31)
# P_avg_test: shape of(31, 31)
# --------data successfully filtered (dvariance)--------
# X_train: shape of(1387, 28, 31)
# X_test: shape of(1487, 28, 31)
# Y_train: shape of(1387, 1)
# Y_test: shape of(1487, 1)
# A_train: shape of(28, 28)
# A_test: shape of(28, 28)
# P_avg_train: shape of(28, 28)
# P_avg_test: shape of(28, 28)

# %%
show_heat_map(dm.P_avg_train)
show_heat_map(dm.conv_avg_train)

# %%
# adjacency generated by convariance
A2 = (dm.conv_avg_train > 10000)# + (dm.conv_avg_train < -8000) 
show_heat_map(A2)
show_heat_map(create_DAD(A2))

# %%
#randomly generated A
b = np.random.randint(-2000,2000,size=dm.conv_avg_train.shape)
A3 = (b + b.T)/2 > 1500
show_heat_map(A3)
show_heat_map(create_DAD(A3))

# %%
n = 8*10**-2
dm.re_threshold(n)
show_heat_map(dm.A_train)
show_heat_map(create_DAD(dm.A_train))
#print(create_DAD(dm.A_train))
Araw =  dm.A_train

# %%
GCNparameters = {
    'body': dm.X_train.shape[2],
    'M': dm.X_train.shape[0],
    'batch_size': 256,
    'n_layers': 1,
    'num_epochs': 1,
    'learning_rate': 1e-3,
    'weight_decay': 5e-3
}
GDEparameters = {
    'body': dm.X_train.shape[2],
    'solver': GDEsolvers.explicit_RK,
    'solver_params': {
    "t0": 0,
    "t1": 0.25,
    "N": 5,
    "b_tableau": GDEsolvers.RK4
     },
    'hidden_layers': 1,
    'M': dm.X_train.shape[0],
    'batch_size': 128,
    'num_epochs': 1,
    'learning_rate': 1e-3,
    'weight_decay': 5e-3
}
RNNparametersGCN = {
    'hidden_dim' : 10,
    'batch_size': 128,
    'num_epochs': 900,
    'learning_rate': 6e-4,
    'weight_decay': 5e-3,
    'betas': (0.9, 0.999), 
    'eps': 1e-08
}
RNNparametersGDE = {
    'hidden_dim' : 10,
    'batch_size': 128,
    'num_epochs': 900,
    'learning_rate': 6e-4,
    'weight_decay': 5e-3,
    'betas': (0.9, 0.999), 
    'eps': 1e-08
}
#print(GCNparameters['M'])

# %%
IM = Integrated_Model_RNN(GCNparameters, GDEparameters, RNNparametersGCN, RNNparametersGDE, dm, create_DAD(Araw))
# Out:
# 100%|██████████| 6/6 [00:00<00:00, 58.98it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
# ----------Training GCN-----------
# device set to cpu
# Epoch: 1   Batch: 6 of size 256   Train loss: 501.040283203125   Valid loss: 500.440063476562565
# ----------Training Ends-----------
# ----------Training GDE-----------
# device set to cpu
#  18%|█▊        | 2/11 [00:00<00:01,  6.22it/s]
# Epoch: 1   Batch: 2 of size 128   Train loss: 506.8283996582031   Valid loss: 505.5686340332031
#  36%|███▋      | 4/11 [00:00<00:01,  6.28it/s]
# Epoch: 1   Batch: 4 of size 128   Train loss: 504.27532958984375   Valid loss: 503.3355407714844
#  55%|█████▍    | 6/11 [00:00<00:00,  6.43it/s]
# Epoch: 1   Batch: 6 of size 128   Train loss: 502.2139892578125   Valid loss: 501.461944580078125
#  73%|███████▎  | 8/11 [00:01<00:00,  6.19it/s]
# Epoch: 1   Batch: 8 of size 128   Train loss: 500.4471435546875   Valid loss: 499.9381408691406
#  91%|█████████ | 10/11 [00:01<00:00,  6.40it/s]
# Epoch: 1   Batch: 10 of size 128   Train loss: 498.7127990722656   Valid loss: 499.03887939453125
# 100%|██████████| 11/11 [00:01<00:00,  6.38it/s]
# Epoch: 1   Batch: 11 of size 128   Train loss: 498.6789855957031   Valid loss: 498.2579650878906
# ----------Training Ends-----------
# ----------Training RNN-----------
# 0.535 ----------saved-----------
# 0.551 ----------saved-----------
# 0.564 ----------saved-----------
# 0.577 ----------saved-----------
# 0.589 ----------saved-----------
# 0.599 ----------saved-----------
# 0.609 ----------saved-----------
# 0.617 ----------saved-----------
# 0.625 ----------saved-----------
# 0.631 ----------saved-----------
# 0.637 ----------saved-----------
# 0.642 ----------saved-----------
# 0.647 ----------saved-----------
# 0.651 ----------saved-----------
# 0.654 ----------saved-----------
# 0.657 ----------saved-----------
# 0.66 ----------saved-----------
# 0.663 ----------saved-----------
# 0.666 ----------saved-----------
# 0.668 ----------saved-----------
# 0.671 ----------saved-----------
# 0.673 ----------saved-----------
# 0.675 ----------saved-----------
# 0.677 ----------saved-----------
# 0.679 ----------saved-----------
# 0.681 ----------saved-----------
# 0.683 ----------saved-----------
# 0.685 ----------saved-----------
# 0.687 ----------saved-----------
# 0.689 ----------saved-----------
# 0.691 ----------saved-----------
# 0.693 ----------saved-----------
# 0.695 ----------saved-----------
# 0.697 ----------saved-----------
# 0.699 ----------saved-----------
# 0.701 ----------saved-----------
# 0.703 ----------saved-----------
# 0.704 ----------saved-----------
# 0.706 ----------saved-----------
# 0.708 ----------saved-----------
# 0.71 ----------saved-----------
# 0.712 ----------saved-----------
# 0.713 ----------saved-----------
# 0.715 ----------saved-----------
# 0.717 ----------saved-----------
# 0.719 ----------saved-----------
# 0.72 ----------saved-----------
# 0.722 ----------saved-----------
# 0.724 ----------saved-----------
# 0.726 ----------saved-----------
# 0.727 ----------saved-----------
# 0.729 ----------saved-----------
# 0.731 ----------saved-----------
# 0.733 ----------saved-----------
# 0.734 ----------saved-----------
# 0.736 ----------saved-----------
# 0.738 ----------saved-----------
# 0.739 ----------saved-----------
# 0.741 ----------saved-----------
# 0.742 ----------saved-----------
# 0.744 ----------saved-----------
# 0.745 ----------saved-----------
# 0.746 ----------saved-----------
# 0.747 ----------saved-----------
# 0.749 ----------saved-----------
# 0.75 ----------saved-----------
# 0.751 ----------saved-----------
# 0.752 ----------saved-----------
# 0.754 ----------saved-----------
# 0.755 ----------saved-----------
# 0.756 ----------saved-----------
# 0.757 ----------saved-----------
# 0.758 ----------saved-----------
# 0.759 ----------saved-----------
# 0.76 ----------saved-----------
# 0.761 ----------saved-----------
# 0.762 ----------saved-----------
# 0.763 ----------saved-----------
# 0.764 ----------saved-----------
# 0.765 ----------saved-----------
# 0.765 ----------saved-----------
# 0.766 ----------saved-----------
# 0.767 ----------saved-----------
# 0.767 ----------saved-----------
# 0.768 ----------saved-----------
# 0.769 ----------saved-----------
# 0.769 ----------saved-----------
# 0.77 ----------saved-----------
# 0.77 ----------saved-----------
# 0.771 ----------saved-----------
# 0.771 ----------saved-----------
# 0.772 ----------saved-----------
# 0.772 ----------saved-----------
# 0.773 ----------saved-----------
# 0.773 ----------saved-----------
# 0.774 ----------saved-----------
# 0.774 ----------saved-----------
# 0.774 ----------saved-----------
# 0.775 ----------saved-----------
# 0.775 ----------saved-----------
# 0.775 ----------saved-----------
# 0.775 ----------saved-----------
# 0.775 ----------saved-----------
# 0.776 ----------saved-----------
# 0.776 ----------saved-----------
# 0.776 ----------saved-----------
# 0.776 ----------saved-----------
# 0.776 ----------saved-----------
# 0.776 ----------saved-----------
# 0.777 ----------saved-----------
# 0.777 ----------saved-----------
# 0.777 ----------saved-----------
# 0.777 ----------saved-----------
# 0.777 ----------saved-----------
# 0.777 ----------saved-----------
# 0.778 ----------saved-----------
# 0.778 ----------saved-----------
# 0.778 ----------saved-----------
# 0.778 ----------saved-----------
# 0.778 ----------saved-----------
# 0.778 ----------saved-----------
# 0.778 ----------saved-----------
# 0.778 ----------saved-----------
# 0.778 ----------saved-----------
# 0.779 ----------saved-----------
# 0.779 ----------saved-----------
# 0.779 ----------saved-----------
# 0.779 ----------saved-----------
# 0.779 ----------saved-----------
# 0.779 ----------saved-----------
# 0.78 ----------saved-----------
# 0.78 ----------saved-----------
# 0.78 ----------saved-----------
# 0.78 ----------saved-----------
# 0.781 ----------saved-----------
# 0.781 ----------saved-----------
# 0.781 ----------saved-----------
# 0.782 ----------saved-----------
# 0.782 ----------saved-----------
# 0.782 ----------saved-----------
# 0.783 ----------saved-----------
# 0.783 ----------saved-----------
# 0.784 ----------saved-----------
# 0.784 ----------saved-----------
# 0.784 ----------saved-----------
# 0.785 ----------saved-----------
# 0.785 ----------saved-----------
# 0.786 ----------saved-----------
# 0.787 ----------saved-----------
# 0.787 ----------saved-----------
# 0.788 ----------saved-----------
# 0.789 ----------saved-----------
# 0.789 ----------saved-----------
# 0.79 ----------saved-----------
# 0.791 ----------saved-----------
# 0.792 ----------saved-----------
# 0.792 ----------saved-----------
# 0.793 ----------saved-----------
# 0.794 ----------saved-----------
# 0.795 ----------saved-----------
# 0.795 ----------saved-----------
# 0.796 ----------saved-----------
# 0.797 ----------saved-----------
# 0.797 ----------saved-----------
# 0.798 ----------saved-----------
# 0.799 ----------saved-----------
# 0.799 ----------saved-----------
# 0.8 ----------saved-----------
# 0.801 ----------saved-----------
# 0.801 ----------saved-----------
# 0.802 ----------saved-----------
# 0.802 ----------saved-----------
# 0.803 ----------saved-----------
# 0.803 ----------saved-----------
# 0.803 ----------saved-----------
# 0.804 ----------saved-----------
# 0.804 ----------saved-----------
# 0.805 ----------saved-----------
# 0.805 ----------saved-----------
# 0.805 ----------saved-----------
# 0.805 ----------saved-----------
# 0.806 ----------saved-----------
# 0.806 ----------saved-----------
# 0.806 ----------saved-----------
# 0.806 ----------saved-----------
# 0.806 ----------saved-----------
# 0.806 ----------saved-----------
# 0.807 ----------saved-----------
# 0.807 ----------saved-----------
# 0.807 ----------saved-----------
# 0.807 ----------saved-----------
# 0.807 ----------saved-----------
# 0.808 ----------saved-----------
# 0.809 ----------saved-----------
# 0.809 ----------saved-----------
# 0.81 ----------saved-----------
# 0.812 ----------saved-----------
# 0.812 ----------saved-----------
# 0.814 ----------saved-----------
# 0.814 ----------saved-----------
# 0.814 ----------saved-----------
# ----------------------------------
# 0.584 ----------saved-----------
# 0.599 ----------saved-----------
# 0.614 ----------saved-----------
# 0.627 ----------saved-----------
# 0.639 ----------saved-----------
# 0.65 ----------saved-----------
# 0.66 ----------saved-----------
# 0.669 ----------saved-----------
# 0.677 ----------saved-----------
# 0.684 ----------saved-----------
# 0.691 ----------saved-----------
# 0.697 ----------saved-----------
# 0.702 ----------saved-----------
# 0.708 ----------saved-----------
# 0.712 ----------saved-----------
# 0.717 ----------saved-----------
# 0.721 ----------saved-----------
# 0.724 ----------saved-----------
# 0.727 ----------saved-----------
# 0.731 ----------saved-----------
# 0.734 ----------saved-----------
# 0.737 ----------saved-----------
# 0.74 ----------saved-----------
# 0.742 ----------saved-----------
# 0.744 ----------saved-----------
# 0.747 ----------saved-----------
# 0.749 ----------saved-----------
# 0.751 ----------saved-----------
# 0.754 ----------saved-----------
# 0.756 ----------saved-----------
# 0.758 ----------saved-----------
# 0.76 ----------saved-----------
# 0.761 ----------saved-----------
# 0.763 ----------saved-----------
# 0.765 ----------saved-----------
# 0.767 ----------saved-----------
# 0.768 ----------saved-----------
# 0.77 ----------saved-----------
# 0.771 ----------saved-----------
# 0.773 ----------saved-----------
# 0.774 ----------saved-----------
# 0.775 ----------saved-----------
# 0.777 ----------saved-----------
# 0.778 ----------saved-----------
# 0.779 ----------saved-----------
# 0.78 ----------saved-----------
# 0.781 ----------saved-----------
# 0.783 ----------saved-----------
# 0.783 ----------saved-----------
# 0.784 ----------saved-----------
# 0.785 ----------saved-----------
# 0.786 ----------saved-----------
# 0.787 ----------saved-----------
# 0.788 ----------saved-----------
# 0.789 ----------saved-----------
# 0.789 ----------saved-----------
# 0.79 ----------saved-----------
# 0.79 ----------saved-----------
# 0.791 ----------saved-----------
# 0.791 ----------saved-----------
# 0.792 ----------saved-----------
# 0.793 ----------saved-----------
# 0.793 ----------saved-----------
# 0.794 ----------saved-----------
# 0.794 ----------saved-----------
# 0.795 ----------saved-----------
# 0.795 ----------saved-----------
# 0.796 ----------saved-----------
# 0.796 ----------saved-----------
# 0.796 ----------saved-----------
# 0.797 ----------saved-----------
# 0.797 ----------saved-----------
# 0.797 ----------saved-----------
# 0.798 ----------saved-----------
# 0.798 ----------saved-----------
# 0.799 ----------saved-----------
# 0.799 ----------saved-----------
# 0.799 ----------saved-----------
# 0.8 ----------saved-----------
# 0.8 ----------saved-----------
# 0.801 ----------saved-----------
# 0.801 ----------saved-----------
# 0.801 ----------saved-----------
# 0.801 ----------saved-----------
# 0.802 ----------saved-----------
# 0.802 ----------saved-----------
# 0.802 ----------saved-----------
# 0.803 ----------saved-----------
# 0.803 ----------saved-----------
# 0.803 ----------saved-----------
# 0.803 ----------saved-----------
# 0.804 ----------saved-----------
# 0.804 ----------saved-----------
# 0.804 ----------saved-----------
# 0.805 ----------saved-----------
# 0.805 ----------saved-----------
# 0.805 ----------saved-----------
# 0.805 ----------saved-----------
# 0.806 ----------saved-----------
# 0.806 ----------saved-----------
# 0.806 ----------saved-----------
# 0.807 ----------saved-----------
# 0.807 ----------saved-----------
# 0.807 ----------saved-----------
# 0.807 ----------saved-----------
# 0.808 ----------saved-----------
# 0.808 ----------saved-----------
# 0.808 ----------saved-----------
# 0.808 ----------saved-----------
# 0.809 ----------saved-----------
# 0.809 ----------saved-----------
# 0.809 ----------saved-----------
# 0.809 ----------saved-----------
# 0.809 ----------saved-----------
# 0.809 ----------saved-----------
# 0.809 ----------saved-----------
# 0.809 ----------saved-----------
# 0.809 ----------saved-----------
# 0.809 ----------saved-----------
# 0.81 ----------saved-----------
# 0.81 ----------saved-----------
# 0.81 ----------saved-----------
# 0.81 ----------saved-----------
# 0.81 ----------saved-----------
# 0.811 ----------saved-----------
# 0.811 ----------saved-----------
# 0.811 ----------saved-----------
# 0.811 ----------saved-----------
# 0.812 ----------saved-----------
# 0.812 ----------saved-----------
# 0.813 ----------saved-----------
# 0.813 ----------saved-----------
# 0.814 ----------saved-----------
# 0.814 ----------saved-----------
# 0.815 ----------saved-----------
# 0.815 ----------saved-----------
# 0.816 ----------saved-----------
# 0.817 ----------saved-----------
# 0.817 ----------saved-----------
# 0.818 ----------saved-----------
# 0.818 ----------saved-----------
# 0.819 ----------saved-----------
# 0.82 ----------saved-----------
# 0.82 ----------saved-----------
# 0.82 ----------saved-----------
# 0.82 ----------saved-----------
# 0.82 ----------saved-----------
# ----------Training Ends-----------

# %%
IM.print_accuracy(dm, Araw, device_name = 'cpu')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-59-fe095b226fe2> in <module>
# ----> 1 IM.print_accuracy(dm, Araw, device_name = 'cuda')
#
# ~\Documents\GitHub\GCNGDE_Simulation_for_EGG_analysis\Full Model\Full_model.py in print_accuracy(self, dm, Araw, device_name)
#     262         # Get simularity matrix from GCN
#     263         GCNmodel.eval()
# --> 264         sim_all["GCN_test"] = GCNmodel(torch.from_numpy(X_test).float().to(device_name),
#     265                                        torch.from_numpy(A).float().to(device_name)).cpu().detach().numpy()
#     266
#
# ~\anaconda3\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# ~\Documents\GitHub\GCNGDE_Simulation_for_EGG_analysis\Full Model\GCN.py in forward(self, h_0, A)
#     151     def forward(self, h_0, A):
#     152         #print(h_0.shape)
# --> 153         x = self.activation(self.head(h_0, A))
#     154         for layer in self.layers:
#     155             x = self.activation(layer(x, A))
#
# ~\anaconda3\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# ~\Documents\GitHub\GCNGDE_Simulation_for_EGG_analysis\Full Model\GCN.py in forward(self, H, A)
#      35     # A, precomputed adj matrix
#      36     def forward(self, H, A):
# ---> 37         n = torch.matmul(A, torch.matmul(H, self.weight))
#      38         if self.bias is not None:
#      39             return n + self.bias
#
# RuntimeError: Tensor for argument #3 'mat2' is on CPU, but expected it to be on GPU (while checking arguments for addmm)
