# %%
# %reload_ext autoreload
# %autoreload 2
#Custom Files
from DataManager import dataManager
from DataManagerUtil import *
import GCN as GCN
import GCNutil as GCNutil
import GDE as GDE
import GDEutil as GDEutil
import GDEsolvers as GDEsolvers
import MLP as MLP
from Full_model import Integrated_Model

#Standard Libraries
# Torch
import torch
import torch.autograd
import torch.nn as nn
import torch.nn.functional as F
#Numpy
import numpy as np

# %%
#Loading everything from the dataset
filepath = 'datasets\pat_FR_620.mat' #264 253 620 273
variables = load_patient_data(filepath, verbose = True)
# Out:
# name: X_test
# shape: (640, 31, 1518)
# -----------------------
# name: X_train
# shape: (640, 31, 1395)
# -----------------------
# name: clip_sizes_test
# shape: (2, 129)
# -----------------------
# name: clip_sizes_train
# shape: (2, 127)
# -----------------------
# name: conv_sizes
# shape: (1, 1)
# -----------------------
# name: n_pre_szr
# shape: (1, 1)
# -----------------------
# name: sel_win_nums_test
# shape: (1, 1518)
# -----------------------
# name: sel_win_nums_train
# shape: (1, 1395)
# -----------------------
# name: soz_ch_ids
# shape: (5, 1)
# -----------------------
# name: stride_sec
# shape: (1, 1)
# -----------------------
# name: window_size_sec
# shape: (1, 1)
# -----------------------
# name: y_test
# shape: (1, 1518)
# -----------------------
# name: y_train
# shape: (1, 1395)
# -----------------------
# print sample EGG signal from one node:

# %%
dm = dataManager(variables["X_train"],variables["X_test"],variables["y_train"],variables["y_test"],10**(-4))
# Out:
# --------data manager successfully initialized--------

# %%
#reduce redundant nodes
#from DataManager import get_label_variance as glv
#print(glv(dm.X_train, dm.Y_train))
#print(np.argsort(glv(dm.X_train, dm.Y_train)))
print(dm)
dm.apply_dvariance_filter(28)
dm.mean_pooling_1d(size = 24, stride = 20, padding = 0)
print(dm)
# Out:
# X_train: shape of(1387, 31, 640)
# X_test: shape of(1487, 31, 640)
# Y_train: shape of(1387, 1)
# Y_test: shape of(1487, 1)
# A_train: shape of(31, 31)
# A_test: shape of(31, 31)
# P_avg_train: shape of(31, 31)
# P_avg_test: shape of(31, 31)
# --------data successfully filtered (dvariance)--------
# X_train: shape of(1387, 28, 31)
# X_test: shape of(1487, 28, 31)
# Y_train: shape of(1387, 1)
# Y_test: shape of(1487, 1)
# A_train: shape of(28, 28)
# A_test: shape of(28, 28)
# P_avg_train: shape of(28, 28)
# P_avg_test: shape of(28, 28)

# %%
show_heat_map(dm.P_avg_train)
show_heat_map(dm.conv_avg_train)

# %%
# adjacency generated by convariance
A2 = (dm.conv_avg_train > 10000)# + (dm.conv_avg_train < -8000) 
show_heat_map(A2)
show_heat_map(create_DAD(A2))

# %%
#randomly generated A
b = np.random.randint(-2000,2000,size=dm.conv_avg_train.shape)
A3 = (b + b.T)/2 > 1500
show_heat_map(A3)
show_heat_map(create_DAD(A3))

# %%
n = 1*10**-1
dm.re_threshold(n)
show_heat_map(dm.A_train)
show_heat_map(create_DAD(dm.A_train))
#print(create_DAD(dm.A_train))
Araw =  dm.A_train

# %%
GCNparameters = {
    'body': dm.X_train.shape[2],
    'M': dm.X_train.shape[0],
    'batch_size': 256,
    'n_layers': 1,
    'num_epochs': 1,
    'learning_rate': 1e-3,
    'weight_decay': 5e-3
}
GDEparameters = {
    'body': dm.X_train.shape[2],
    'solver': GDEsolvers.explicit_RK,
    'solver_params': {
    "t0": 0,
    "t1": 0.25,
    "N": 5,
    "b_tableau": GDEsolvers.RK4
     },
    'hidden_layers': 1,
    'M': dm.X_train.shape[0],
    'batch_size': 128,
    'num_epochs': 1,
    'learning_rate': 1e-3,
    'weight_decay': 5e-3
}
MLPparametersGCN = {
    'n_layers':2,
    'layer_size_factor':[1,50], 
    'dropout':[0.3, 0.15],
    'batch_size': 128,
    'num_epochs': 900,
    'learning_rate': 6e-4,
    'weight_decay': 5e-3,
    'betas': (0.9, 0.999), 
    'eps': 1e-08
}
MLPparametersGDE = {
    'n_layers':2,
    'layer_size_factor':[1, 50], 
    'dropout':[0.3, 0.15],
    'batch_size': 128,
    'num_epochs': 900,
    'learning_rate': 6e-4,
    'weight_decay': 5e-3,
    'betas': (0.9, 0.999), 
    'eps': 1e-08
}
#print(GCNparameters['M'])

# %%
IM = Integrated_Model(GCNparameters, GDEparameters, MLPparametersGCN, MLPparametersGDE, dm, create_DAD(Araw))
# Out:
# 100%|██████████| 6/6 [00:00<00:00, 57.85it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
# ----------Training GCN-----------
# device set to cpu
# Epoch: 1   Batch: 6 of size 256   Train loss: 388.7226867675781   Valid loss: 387.858306884765675
# ----------Training Ends-----------
# ----------Training GDE-----------
# device set to cpu
#  18%|█▊        | 2/11 [00:00<00:01,  7.02it/s]
# Epoch: 1   Batch: 2 of size 128   Train loss: 391.14227294921875   Valid loss: 389.98956298828125
#  36%|███▋      | 4/11 [00:00<00:00,  7.13it/s]
# Epoch: 1   Batch: 4 of size 128   Train loss: 388.59295654296875   Valid loss: 387.71173095703125
#  55%|█████▍    | 6/11 [00:00<00:00,  7.13it/s]
# Epoch: 1   Batch: 6 of size 128   Train loss: 386.5887451171875   Valid loss: 385.68066406255
#  73%|███████▎  | 8/11 [00:01<00:00,  7.08it/s]
# Epoch: 1   Batch: 8 of size 128   Train loss: 384.5142822265625   Valid loss: 384.36016845703125
#  91%|█████████ | 10/11 [00:01<00:00,  7.06it/s]
# Epoch: 1   Batch: 10 of size 128   Train loss: 382.99298095703125   Valid loss: 382.9015808105469
# 100%|██████████| 11/11 [00:01<00:00,  7.14it/s]
# Epoch: 1   Batch: 11 of size 128   Train loss: 382.1334533691406   Valid loss: 382.2168273925781
# ----------Training Ends-----------
# Average Ictal and Non-Ictal Simularity Matrix for GCN
# Average ictal
# Average Non-Ictal
# Average Ictal and Non-Ictal Simularity Matrix for GDE
# Average ictal
# Average Non-Ictal
# Sample Ictal and Non-Ictal Simularity Matrix for GCN
# sample ictal
# sample Non-Ictal
# Sample Ictal and Non-Ictal Simularity Matrix for GDE
# sample ictal
# sample Non-Ictal
# ----------Training MLP-----------
# 0.771 ----------saved-----------
# 0.778 ----------saved-----------
# 0.782 ----------saved-----------
# 0.788 ----------saved-----------
# ----------------------------------
# 0.513 ----------saved-----------
# 0.547 ----------saved-----------
# 0.594 ----------saved-----------
# 0.635 ----------saved-----------
# 0.665 ----------saved-----------
# 0.685 ----------saved-----------
# 0.701 ----------saved-----------
# 0.715 ----------saved-----------
# 0.728 ----------saved-----------
# 0.74 ----------saved-----------
# 0.749 ----------saved-----------
# 0.764 ----------saved-----------
# 0.775 ----------saved-----------
# 0.78 ----------saved-----------
# 0.788 ----------saved-----------
# 0.793 ----------saved-----------
# 0.798 ----------saved-----------
# 0.803 ----------saved-----------
# 0.806 ----------saved-----------
# 0.806 ----------saved-----------
# 0.807 ----------saved-----------
# 0.809 ----------saved-----------
# 0.811 ----------saved-----------
# 0.812 ----------saved-----------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-45557865e14e> in <module>
# ----> 1 IM = Integrated_Model(GCNparameters, GDEparameters, MLPparametersGCN, MLPparametersGDE, dm, create_DAD(Araw))
#
# ~\Documents\GitHub\GCNGDE_Simulation_for_EGG_analysis\Full Model\Full_model.py in __init__(self, GCNparams, GDEparams, MLPGCNparams, MLPGDEparams, dm, Araw)
#      27         self.GCNmodel, self.GCNcheckpoint = self.train_GCN(dm, Araw)
#      28         self.GDEmodel, self.GDEcheckpoint = self.train_GDE(dm, Araw)
# ---> 29         self.MLPmodelGCN, self.MLPmodelGDE, self.MLPcheckpointGCN, self.MLPcheckpointGDE = self.train_MLP(dm, Araw, device_name = 'cpu',acc_fn = MLP.auc2, plot_avg_matrix = True, plot_sample_matrix = True)
#      30
#      31     def train_GCN(self, dm, Araw, device_name = 'cpu'):
#
# ~\Documents\GitHub\GCNGDE_Simulation_for_EGG_analysis\Full Model\Full_model.py in train_MLP(self, dm, Araw, device_name, acc_fn, plot_avg_matrix, plot_sample_matrix)
#      93                                                             print_summary=False, verbose=False)
#      94         print("----------------------------------")
# ---> 95         MLPmodelGDE, _, _, MLPcheckpointGDE = MLP.train_MLP(dm, sim_all["GDE_train"], sim_all["GDE_test"],
#      96                                                             self.MLPGDEparams, acc_fn=acc_fn, autostop_decay=0.995,
#      97                                                             print_summary=False, verbose=False)
#
# ~\Documents\GitHub\GCNGDE_Simulation_for_EGG_analysis\Full Model\MLP.py in train_MLP(dm, sim_train, sim_test, parameters, acc_fn, autostop_decay, print_summary, verbose)
#     342             val_pred = MLPmodel(X_test)
#     343             val_loss = criterion(val_pred, Y_test)
# --> 344             tva = acc_fn(val_pred, Y_test, threshold=t)
#     345             if tva > val_acc:
#     346                 val_acc = tva
#
# ~\Documents\GitHub\GCNGDE_Simulation_for_EGG_analysis\Full Model\MLP.py in auc2(y_pred, y_true, threshold)
#     259
#     260 def auc2(y_pred, y_true, threshold = None):
# --> 261     fpr, tpr, thresholds = metrics.roc_curve(y_true.cpu().detach().numpy(), y_pred.cpu().detach().numpy(), pos_label=1)
#     262     return metrics.auc(fpr, tpr)
#     263
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~\anaconda3\lib\site-packages\sklearn\metrics\_ranking.py in roc_curve(y_true, y_score, pos_label, sample_weight, drop_intermediate)
#     788         optimal_idxs = np.where(np.r_[True,
#     789                                       np.logical_or(np.diff(fps, 2),
# --> 790                                                     np.diff(tps, 2)),
#     791                                       True])[0]
#     792         fps = fps[optimal_idxs]
#
# <__array_function__ internals> in diff(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\numpy\lib\function_base.py in diff(a, n, axis, prepend, append)
#    1278     op = not_equal if a.dtype == np.bool_ else subtract
#    1279     for _ in range(n):
# -> 1280         a = op(a[slice1], a[slice2])
#    1281
#    1282     return a
#
# KeyboardInterrupt:

# %%
IM.print_accuracy(dm, Araw, device_name = 'cpu')
