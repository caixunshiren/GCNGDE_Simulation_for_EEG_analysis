# %%
# %reload_ext autoreload
# %autoreload 2
#Custom Files
from DataManager import dataManager
from DataManagerUtil import *
import GCN as GCN
import GCNutil as GCNutil
import GDE as GDE
import GDEutil as GDEutil
import GDEsolvers as GDEsolvers
import MLP as MLP
from Full_model import Integrated_Model

#Standard Libraries
# Torch
import torch
import torch.autograd
import torch.nn as nn
import torch.nn.functional as F
#Numpy
import numpy as np

# %%
#Loading everything from the dataset
filepath = 'datasets\pat_FR_273.mat' #264 253 620 273
variables = load_patient_data(filepath, verbose = True)
# Out:
# name: X_test
# shape: (640, 35, 2649)
# -----------------------
# name: X_train
# shape: (640, 35, 2564)
# -----------------------
# name: clip_sizes_test
# shape: (2, 102)
# -----------------------
# name: clip_sizes_train
# shape: (2, 101)
# -----------------------
# name: conv_sizes
# shape: (1, 1)
# -----------------------
# name: n_pre_szr
# shape: (1, 1)
# -----------------------
# name: sel_win_nums_test
# shape: (1, 2649)
# -----------------------
# name: sel_win_nums_train
# shape: (1, 2564)
# -----------------------
# name: soz_ch_ids
# shape: (7, 1)
# -----------------------
# name: stride_sec
# shape: (1, 1)
# -----------------------
# name: window_size_sec
# shape: (1, 1)
# -----------------------
# name: y_test
# shape: (1, 2649)
# -----------------------
# name: y_train
# shape: (1, 2564)
# -----------------------
# print sample EGG signal from one node:

# %%
dm = dataManager(variables["X_train"],variables["X_test"],variables["y_train"],variables["y_test"],10**(-4))
# Out:
# --------data manager successfully initialized--------

# %%
#reduce redundant nodes
#from DataManager import get_label_variance as glv
#print(glv(dm.X_train, dm.Y_train))
#print(np.argsort(glv(dm.X_train, dm.Y_train)))
print(dm)
dm.apply_dvariance_filter(28)
dm.mean_pooling_1d(size = 24, stride = 20, padding = 0)
print(dm)
# Out:
# X_train: shape of(2562, 35, 640)
# X_test: shape of(2649, 35, 640)
# Y_train: shape of(2562, 1)
# Y_test: shape of(2649, 1)
# A_train: shape of(35, 35)
# A_test: shape of(35, 35)
# P_avg_train: shape of(35, 35)
# P_avg_test: shape of(35, 35)
# --------data successfully filtered (dvariance)--------
# X_train: shape of(2562, 28, 31)
# X_test: shape of(2649, 28, 31)
# Y_train: shape of(2562, 1)
# Y_test: shape of(2649, 1)
# A_train: shape of(28, 28)
# A_test: shape of(28, 28)
# P_avg_train: shape of(28, 28)
# P_avg_test: shape of(28, 28)

# %%
show_heat_map(dm.P_avg_train)
show_heat_map(dm.conv_avg_train)

# %%
# adjacency generated by convariance
A2 = (dm.conv_avg_train > 10000)# + (dm.conv_avg_train < -8000) 
show_heat_map(A2)
show_heat_map(create_DAD(A2))

# %%
#randomly generated A
b = np.random.randint(-2000,2000,size=dm.conv_avg_train.shape)
A3 = (b + b.T)/2 > 1500
show_heat_map(A3)
show_heat_map(create_DAD(A3))

# %%
n = 1000.5*10**-3
dm.re_threshold(n)
show_heat_map(dm.A_train)
show_heat_map(create_DAD(dm.A_train))
#print(create_DAD(dm.A_train))
Araw =  A3#dm.A_train

# %%
GCNparameters = {
    'body': dm.X_train.shape[2],
    'M': dm.X_train.shape[0],
    'batch_size': 256,
    'n_layers': 2,
    'num_epochs': 1,
    'learning_rate': 1e-3,
    'weight_decay': 5e-3
}
GDEparameters = {
    'body': dm.X_train.shape[2],
    'solver': GDEsolvers.explicit_RK,
    'solver_params': {
    "t0": 0,
    "t1": 0.25,
    "N": 5,
    "b_tableau": GDEsolvers.EF
     },
    'hidden_layers': 1,
    'M': dm.X_train.shape[0],
    'batch_size': 128,
    'num_epochs': 1,
    'learning_rate': 1e-3,
    'weight_decay': 5e-3
}
MLPparametersGCN = {
    'n_layers':2,
    'layer_size_factor':[1,50], 
    'dropout':[0.3, 0.15],
    'batch_size': 128,
    'num_epochs': 900,
    'learning_rate': 6e-4,
    'weight_decay': 5e-3,
    'betas': (0.9, 0.999), 
    'eps': 1e-08
}
MLPparametersGDE = {
    'n_layers':2,
    'layer_size_factor':[1, 50], 
    'dropout':[0.3, 0.15],
    'batch_size': 128,
    'num_epochs': 900,
    'learning_rate': 6e-4,
    'weight_decay': 5e-3,
    'betas': (0.9, 0.999), 
    'eps': 1e-08
}
#print(GCNparameters['M'])

# %%
IM = Integrated_Model(GCNparameters, GDEparameters, MLPparametersGCN, MLPparametersGDE, dm, create_DAD(A3))
# Out:
#  55%|█████▍    | 6/11 [00:00<00:00, 51.86it/s]
# ----------Training GCN-----------
# device set to cpu
# Epoch: 1   Batch: 9 of size 256   Train loss: 154.722412109375   Valid loss: 153.4021301269531288
# 100%|██████████| 11/11 [00:00<00:00, 55.42it/s]
#  19%|█▉        | 4/21 [00:00<00:00, 32.36it/s]
# Epoch: 1   Batch: 11 of size 256   Train loss: 151.15684509277344   Valid loss: 150.49349975585938
# ----------Training Ends-----------
# ----------Training GDE-----------
# device set to cpu
# Epoch: 1   Batch: 5 of size 128   Train loss: 158.9061737060547   Valid loss: 157.448181152343755
#  57%|█████▋    | 12/21 [00:00<00:00, 32.48it/s]
# Epoch: 1   Batch: 12 of size 128   Train loss: 148.56515502929688   Valid loss: 147.50701904296875
#  76%|███████▌  | 16/21 [00:00<00:00, 32.28it/s]
# Epoch: 1   Batch: 18 of size 128   Train loss: 140.9624786376953   Valid loss: 139.895217895507825
# 100%|██████████| 21/21 [00:00<00:00, 32.77it/s]
# Epoch: 1   Batch: 21 of size 128   Train loss: 139.62252807617188   Valid loss: 137.38409423828125
# ----------Training Ends-----------
# ----------Training MLP-----------
# 0.703 ----------saved-----------
# 0.725 ----------saved-----------
# 0.741 ----------saved-----------
# 0.76 ----------saved-----------
# 0.779 ----------saved-----------
# 0.793 ----------saved-----------
# 0.801 ----------saved-----------
# 0.808 ----------saved-----------
# 0.813 ----------saved-----------
# 0.818 ----------saved-----------
# 0.822 ----------saved-----------
# 0.828 ----------saved-----------
# 0.832 ----------saved-----------
# 0.838 ----------saved-----------
# 0.84 ----------saved-----------
# 0.843 ----------saved-----------
# 0.847 ----------saved-----------
# 0.851 ----------saved-----------
# 0.855 ----------saved-----------
# 0.859 ----------saved-----------
# 0.861 ----------saved-----------
# 0.866 ----------saved-----------
# 0.868 ----------saved-----------
# 0.871 ----------saved-----------
# 0.874 ----------saved-----------
# 0.875 ----------saved-----------
# 0.876 ----------saved-----------
# 0.878 ----------saved-----------
# 0.88 ----------saved-----------
# 0.883 ----------saved-----------
# 0.886 ----------saved-----------
# 0.891 ----------saved-----------
# 0.893 ----------saved-----------
# 0.894 ----------saved-----------
# 0.894 ----------saved-----------
# 0.895 ----------saved-----------
# 0.895 ----------saved-----------
# 0.896 ----------saved-----------
# 0.896 ----------saved-----------
# 0.896 ----------saved-----------
# 0.896 ----------saved-----------
# 0.897 ----------saved-----------
# 0.898 ----------saved-----------
# 0.898 ----------saved-----------
# 0.899 ----------saved-----------
# 0.899 ----------saved-----------
# 0.9 ----------saved-----------
# 0.9 ----------saved-----------
# 0.901 ----------saved-----------
# 0.901 ----------saved-----------
# 0.903 ----------saved-----------
# 0.907 ----------saved-----------
# 0.908 ----------saved-----------
# 0.908 ----------saved-----------
# 0.908 ----------saved-----------
# 0.908 ----------saved-----------
# 0.908 ----------saved-----------
# 0.909 ----------saved-----------
# 0.911 ----------saved-----------
# 0.911 ----------saved-----------
# 0.911 ----------saved-----------
# 0.912 ----------saved-----------
# 0.912 ----------saved-----------
# 0.913 ----------saved-----------
# 0.913 ----------saved-----------
# 0.913 ----------saved-----------
# 0.913 ----------saved-----------
# 0.913 ----------saved-----------
# 0.913 ----------saved-----------
# 0.914 ----------saved-----------
# 0.914 ----------saved-----------
# 0.914 ----------saved-----------
# 0.914 ----------saved-----------
# 0.915 ----------saved-----------
# 0.916 ----------saved-----------
# 0.916 ----------saved-----------
# 0.916 ----------saved-----------
# 0.918 ----------saved-----------
# 0.918 ----------saved-----------
# 0.666 ----------saved-----------
# 0.731 ----------saved-----------
# 0.77 ----------saved-----------
# 0.79 ----------saved-----------
# 0.807 ----------saved-----------
# 0.823 ----------saved-----------
# 0.834 ----------saved-----------
# 0.843 ----------saved-----------
# 0.849 ----------saved-----------
# 0.856 ----------saved-----------
# 0.862 ----------saved-----------
# 0.868 ----------saved-----------
# 0.872 ----------saved-----------
# 0.877 ----------saved-----------
# 0.883 ----------saved-----------
# 0.885 ----------saved-----------
# 0.887 ----------saved-----------
# 0.891 ----------saved-----------
# 0.894 ----------saved-----------
# 0.898 ----------saved-----------
# 0.9 ----------saved-----------
# 0.901 ----------saved-----------
# 0.902 ----------saved-----------
# 0.904 ----------saved-----------
# 0.906 ----------saved-----------
# 0.908 ----------saved-----------
# 0.909 ----------saved-----------
# 0.91 ----------saved-----------
# 0.911 ----------saved-----------
# 0.911 ----------saved-----------
# 0.911 ----------saved-----------
# 0.913 ----------saved-----------
# 0.914 ----------saved-----------
# 0.915 ----------saved-----------
# 0.916 ----------saved-----------
# 0.916 ----------saved-----------
# 0.917 ----------saved-----------
# 0.917 ----------saved-----------
# 0.918 ----------saved-----------
# 0.918 ----------saved-----------
# 0.919 ----------saved-----------
# 0.919 ----------saved-----------
# 0.92 ----------saved-----------
# 0.92 ----------saved-----------
# 0.921 ----------saved-----------
# 0.921 ----------saved-----------
# 0.922 ----------saved-----------
# 0.922 ----------saved-----------
# 0.922 ----------saved-----------
# 0.923 ----------saved-----------
# 0.923 ----------saved-----------
# 0.923 ----------saved-----------
# 0.924 ----------saved-----------
# 0.926 ----------saved-----------
# 0.927 ----------saved-----------
# 0.929 ----------saved-----------
# ----------Training Ends-----------

# %%
IM.print_accuracy(dm, Araw, device_name = 'cpu')
# Out:
# GCN accuracy:
# device set to cuda
# threshold: 0.05  validation loss: 0.1787 F1 accuracy 0.515 Precision accuracy 0.369 Recall accuracy 0.854 AUC accuracy: 0.918
# device set to cuda
# threshold: 0.1  validation loss: 0.1787 F1 accuracy 0.625 Precision accuracy 0.524 Recall accuracy 0.773 AUC accuracy: 0.918
# device set to cuda
# threshold: 0.15  validation loss: 0.1787 F1 accuracy 0.668 Precision accuracy 0.621 Recall accuracy 0.722 AUC accuracy: 0.918
# device set to cuda
# threshold: 0.2  validation loss: 0.1787 F1 accuracy 0.678 Precision accuracy 0.682 Recall accuracy 0.675 AUC accuracy: 0.918
# device set to cuda
# threshold: 0.25  validation loss: 0.1787 F1 accuracy 0.706 Precision accuracy 0.771 Recall accuracy 0.651 AUC accuracy: 0.918
# device set to cuda
# threshold: 0.3  validation loss: 0.1787 F1 accuracy 0.706 Precision accuracy 0.808 Recall accuracy 0.627 AUC accuracy: 0.918
# device set to cuda
# threshold: 0.35  validation loss: 0.1787 F1 accuracy 0.716 Precision accuracy 0.865 Recall accuracy 0.61 AUC accuracy: 0.918
# device set to cuda
# threshold: 0.4  validation loss: 0.1787 F1 accuracy 0.7 Precision accuracy 0.89 Recall accuracy 0.576 AUC accuracy: 0.918
# device set to cuda
# threshold: 0.45  validation loss: 0.1787 F1 accuracy 0.706 Precision accuracy 0.949 Recall accuracy 0.563 AUC accuracy: 0.918
# device set to cuda
# threshold: 0.5  validation loss: 0.1787 F1 accuracy 0.688 Precision accuracy 0.952 Recall accuracy 0.539 AUC accuracy: 0.918
# device set to cuda
# threshold: 0.55  validation loss: 0.1787 F1 accuracy 0.667 Precision accuracy 0.968 Recall accuracy 0.508 AUC accuracy: 0.918
# device set to cuda
# threshold: 0.6  validation loss: 0.1787 F1 accuracy 0.644 Precision accuracy 0.973 Recall accuracy 0.481 AUC accuracy: 0.918
# device set to cuda
# threshold: 0.65  validation loss: 0.1787 F1 accuracy 0.609 Precision accuracy 0.985 Recall accuracy 0.441 AUC accuracy: 0.918
# device set to cuda
# threshold: 0.7  validation loss: 0.1787 F1 accuracy 0.589 Precision accuracy 0.984 Recall accuracy 0.42 AUC accuracy: 0.918
# device set to cuda
# threshold: 0.75  validation loss: 0.1787 F1 accuracy 0.548 Precision accuracy 0.982 Recall accuracy 0.38 AUC accuracy: 0.918
# device set to cuda
# threshold: 0.8  validation loss: 0.1787 F1 accuracy 0.52 Precision accuracy 0.99 Recall accuracy 0.353 AUC accuracy: 0.918
# device set to cuda
# threshold: 0.85  validation loss: 0.1787 F1 accuracy 0.468 Precision accuracy 1.0 Recall accuracy 0.305 AUC accuracy: 0.918
# device set to cuda
# threshold: 0.9  validation loss: 0.1787 F1 accuracy 0.384 Precision accuracy 1.0 Recall accuracy 0.237 AUC accuracy: 0.918
# device set to cuda
# threshold: 0.95  validation loss: 0.1787 F1 accuracy 0.223 Precision accuracy 1.0 Recall accuracy 0.125 AUC accuracy: 0.918
# device set to cuda
# GDE accuracy:
# device set to cuda
# threshold: 0.05  validation loss: 0.1615 F1 accuracy 0.493 Precision accuracy 0.338 Recall accuracy 0.912 AUC accuracy: 0.929
# device set to cuda
# threshold: 0.1  validation loss: 0.1615 F1 accuracy 0.581 Precision accuracy 0.441 Recall accuracy 0.851 AUC accuracy: 0.929
# device set to cuda
# threshold: 0.15  validation loss: 0.1615 F1 accuracy 0.63 Precision accuracy 0.514 Recall accuracy 0.814 AUC accuracy: 0.929
# device set to cuda
# threshold: 0.2  validation loss: 0.1615 F1 accuracy 0.67 Precision accuracy 0.577 Recall accuracy 0.797 AUC accuracy: 0.929
# device set to cuda
# threshold: 0.25  validation loss: 0.1615 F1 accuracy 0.69 Precision accuracy 0.623 Recall accuracy 0.773 AUC accuracy: 0.929
# device set to cuda
# threshold: 0.3  validation loss: 0.1615 F1 accuracy 0.705 Precision accuracy 0.663 Recall accuracy 0.753 AUC accuracy: 0.929
# device set to cuda
# threshold: 0.35  validation loss: 0.1615 F1 accuracy 0.719 Precision accuracy 0.701 Recall accuracy 0.739 AUC accuracy: 0.929
# device set to cuda
# threshold: 0.4  validation loss: 0.1615 F1 accuracy 0.742 Precision accuracy 0.759 Recall accuracy 0.725 AUC accuracy: 0.929
# device set to cuda
# threshold: 0.45  validation loss: 0.1615 F1 accuracy 0.734 Precision accuracy 0.77 Recall accuracy 0.702 AUC accuracy: 0.929
# device set to cuda
# threshold: 0.5  validation loss: 0.1615 F1 accuracy 0.738 Precision accuracy 0.804 Recall accuracy 0.681 AUC accuracy: 0.929
# device set to cuda
# threshold: 0.55  validation loss: 0.1615 F1 accuracy 0.752 Precision accuracy 0.844 Recall accuracy 0.678 AUC accuracy: 0.929
# device set to cuda
# threshold: 0.6  validation loss: 0.1615 F1 accuracy 0.749 Precision accuracy 0.863 Recall accuracy 0.661 AUC accuracy: 0.929
# device set to cuda
# threshold: 0.65  validation loss: 0.1615 F1 accuracy 0.748 Precision accuracy 0.892 Recall accuracy 0.644 AUC accuracy: 0.929
# device set to cuda
# threshold: 0.7  validation loss: 0.1615 F1 accuracy 0.737 Precision accuracy 0.902 Recall accuracy 0.624 AUC accuracy: 0.929
# device set to cuda
# threshold: 0.75  validation loss: 0.1615 F1 accuracy 0.726 Precision accuracy 0.926 Recall accuracy 0.597 AUC accuracy: 0.929
# device set to cuda
# threshold: 0.8  validation loss: 0.1615 F1 accuracy 0.706 Precision accuracy 0.928 Recall accuracy 0.569 AUC accuracy: 0.929
# device set to cuda
# threshold: 0.85  validation loss: 0.1615 F1 accuracy 0.685 Precision accuracy 0.941 Recall accuracy 0.539 AUC accuracy: 0.929
# device set to cuda
# threshold: 0.9  validation loss: 0.1615 F1 accuracy 0.656 Precision accuracy 0.973 Recall accuracy 0.495 AUC accuracy: 0.929
# device set to cuda
# threshold: 0.95  validation loss: 0.1615 F1 accuracy 0.577 Precision accuracy 0.992 Recall accuracy 0.407 AUC accuracy: 0.929
# device set to cuda
