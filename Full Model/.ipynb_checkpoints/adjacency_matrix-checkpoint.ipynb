# %%
# %reload_ext autoreload
# %autoreload 2
#Custom Files
from DataManager import dataManager
from DataManagerUtil import *
import GCN as GCN
import GCNutil as GCNutil
import GDE as GDE
import GDEutil as GDEutil
import GDEsolvers as GDEsolvers
import MLP as MLP
from Full_model import Integrated_Model

#Standard Libraries
# Torch
import torch
import torch.autograd
import torch.nn as nn
import torch.nn.functional as F
#Numpy
import numpy as np

# %%
#Loading everything from the dataset
filepath = 'datasets\pat_FR_273.mat' #264 253 620 273
variables = load_patient_data(filepath, verbose = True)
# Out:
# name: X_test
# shape: (640, 35, 2649)
# -----------------------
# name: X_train
# shape: (640, 35, 2564)
# -----------------------
# name: clip_sizes_test
# shape: (2, 102)
# -----------------------
# name: clip_sizes_train
# shape: (2, 101)
# -----------------------
# name: conv_sizes
# shape: (1, 1)
# -----------------------
# name: n_pre_szr
# shape: (1, 1)
# -----------------------
# name: sel_win_nums_test
# shape: (1, 2649)
# -----------------------
# name: sel_win_nums_train
# shape: (1, 2564)
# -----------------------
# name: soz_ch_ids
# shape: (7, 1)
# -----------------------
# name: stride_sec
# shape: (1, 1)
# -----------------------
# name: window_size_sec
# shape: (1, 1)
# -----------------------
# name: y_test
# shape: (1, 2649)
# -----------------------
# name: y_train
# shape: (1, 2564)
# -----------------------
# print sample EGG signal from one node:

# %%
dm = dataManager(variables["X_train"],variables["X_test"],variables["y_train"],variables["y_test"],10**(-4))
# Out:
# --------data manager successfully initialized--------

# %%
#reduce redundant nodes
#from DataManager import get_label_variance as glv
#print(glv(dm.X_train, dm.Y_train))
#print(np.argsort(glv(dm.X_train, dm.Y_train)))
print(dm)
#dm.apply_dvariance_filter(30)
#dm.mean_pooling_1d(size = 15, stride = 13, padding = 0)
print(dm)
# Out:
# X_train: shape of(2562, 35, 640)
# X_test: shape of(2649, 35, 640)
# Y_train: shape of(2562, 1)
# Y_test: shape of(2649, 1)
# A_train: shape of(35, 35)
# A_test: shape of(35, 35)
# P_avg_train: shape of(35, 35)
# P_avg_test: shape of(35, 35)
# X_train: shape of(2562, 35, 640)
# X_test: shape of(2649, 35, 640)
# Y_train: shape of(2562, 1)
# Y_test: shape of(2649, 1)
# A_train: shape of(35, 35)
# A_test: shape of(35, 35)
# P_avg_train: shape of(35, 35)
# P_avg_test: shape of(35, 35)

# %%
show_heat_map(dm.P_avg_train)
show_heat_map(dm.conv_avg_train)

# %%
# adjacency generated by convariance
A2 = (dm.conv_avg_train > 10000)# + (dm.conv_avg_train < -8000) 
show_heat_map(A2)
show_heat_map(create_DAD(A2))

# %%
#randomly generated A
N = 100
b = np.random.random_integers(-2000,2000,size=dm.conv_avg_train.shape)
b_symm = (b + b.T)/2

# %%
n = 55555*10**-4
dm.re_threshold(n)
show_heat_map(dm.A_train)
show_heat_map(create_DAD(dm.A_train))
Araw = A2 #dm.A_train

# %%
GCNparameters = {
    'body': dm.X_train.shape[2],
    'M': dm.X_train.shape[0],
    'batch_size': 512,
    'n_layers': 2,
    'num_epochs': 1,
    'learning_rate': 1e-3,
    'weight_decay': 5e-3
}
GDEparameters = {
    'body': dm.X_train.shape[2],
    'solver': GDEsolvers.explicit_RK,
    'solver_params': {
    "t0": 0,
    "t1": 0.25,
    "N": 5,
    "b_tableau": GDEsolvers.EF
     },
    'hidden_layers': 1,
    'M': dm.X_train.shape[0],
    'batch_size': 128,
    'num_epochs': 1,
    'learning_rate': 1e-3,
    'weight_decay': 5e-3
}
MLPparametersGCN = {
    'n_layers':2,
    'layer_size_factor':[1,1], 
    'dropout':[0.3, 0.3],
    'batch_size': 128,
    'num_epochs': 900,
    'learning_rate': 6e-4,
    'weight_decay': 5e-3,
    'betas': (0.9, 0.999), 
    'eps': 1e-08
}
MLPparametersGDE = {
    'n_layers':2,
    'layer_size_factor':[1, 64], 
    'dropout':[0.3, 0.3],
    'batch_size': 128,
    'num_epochs': 900,
    'learning_rate': 6e-4,
    'weight_decay': 5e-3,
    'betas': (0.9, 0.999), 
    'eps': 1e-08
}
#print(GCNparameters['M'])

# %%
IM = Integrated_Model(GCNparameters, GDEparameters, MLPparametersGCN, MLPparametersGDE, dm, Araw)
# Out:
#   0%|          | 0/6 [00:00<?, ?it/s]
# ----------Training GCN-----------
# device set to cpu
#  17%|█▋        | 1/6 [00:01<00:06,  1.26s/it]
# Epoch: 1   Batch: 1 of size 512   Train loss: 173.8861083984375   Valid loss: 128.27542114257812
#  33%|███▎      | 2/6 [00:02<00:05,  1.26s/it]
# Epoch: 1   Batch: 2 of size 512   Train loss: 128.224853515625   Valid loss: 94.49681091308594
#  50%|█████     | 3/6 [00:03<00:03,  1.28s/it]
# Epoch: 1   Batch: 3 of size 512   Train loss: 93.66407775878906   Valid loss: 73.7687759399414
#  67%|██████▋   | 4/6 [00:05<00:02,  1.29s/it]
# Epoch: 1   Batch: 4 of size 512   Train loss: 73.93425750732422   Valid loss: 65.31588745117188
# 100%|██████████| 6/6 [00:06<00:00,  1.11s/it]
# Epoch: 1   Batch: 6 of size 512   Train loss: 70.68783569335938   Valid loss: 70.14323425292969
# ----------Training Ends-----------
# ----------Training GDE-----------
#   0%|          | 0/21 [00:00<?, ?it/s]
# device set to cpu
#   5%|▍         | 1/21 [00:02<00:43,  2.18s/it]
# Epoch: 1   Batch: 1 of size 128   Train loss: 174.07528686523438   Valid loss: 128.6210479736328
#  10%|▉         | 2/21 [00:04<00:40,  2.14s/it]
# Epoch: 1   Batch: 2 of size 128   Train loss: 128.79881286621094   Valid loss: 93.9908447265625
#  14%|█▍        | 3/21 [00:06<00:38,  2.13s/it]
# Epoch: 1   Batch: 3 of size 128   Train loss: 94.12960052490234   Valid loss: 71.0608901977539
#  19%|█▉        | 4/21 [00:08<00:36,  2.12s/it]
# Epoch: 1   Batch: 4 of size 128   Train loss: 72.12516021728516   Valid loss: 63.49675369262695
#  24%|██▍       | 5/21 [00:10<00:33,  2.11s/it]
# Epoch: 1   Batch: 5 of size 128   Train loss: 63.02803421020508   Valid loss: 62.68931579589844
#  29%|██▊       | 6/21 [00:12<00:31,  2.11s/it]
# Epoch: 1   Batch: 6 of size 128   Train loss: 61.62946701049805   Valid loss: 66.14127349853516
#  33%|███▎      | 7/21 [00:14<00:29,  2.10s/it]
# Epoch: 1   Batch: 7 of size 128   Train loss: 65.22791290283203   Valid loss: 65.8460922241211
#  38%|███▊      | 8/21 [00:16<00:26,  2.07s/it]
# Epoch: 1   Batch: 8 of size 128   Train loss: 67.68161010742188   Valid loss: 69.27145385742188
#  43%|████▎     | 9/21 [00:18<00:25,  2.08s/it]
# Epoch: 1   Batch: 9 of size 128   Train loss: 70.5709228515625   Valid loss: 71.51029968261719
#  48%|████▊     | 10/21 [00:21<00:23,  2.11s/it]
# Epoch: 1   Batch: 10 of size 128   Train loss: 70.62545776367188   Valid loss: 73.3988265991211
#  52%|█████▏    | 11/21 [00:23<00:21,  2.13s/it]
# Epoch: 1   Batch: 11 of size 128   Train loss: 73.79440307617188   Valid loss: 75.158447265625
#  57%|█████▋    | 12/21 [00:25<00:19,  2.11s/it]
# Epoch: 1   Batch: 12 of size 128   Train loss: 73.19465637207031   Valid loss: 74.51898193359375
#  62%|██████▏   | 13/21 [00:27<00:16,  2.11s/it]
# Epoch: 1   Batch: 13 of size 128   Train loss: 74.60325622558594   Valid loss: 72.31731414794922
#  67%|██████▋   | 14/21 [00:29<00:14,  2.08s/it]
# Epoch: 1   Batch: 14 of size 128   Train loss: 73.53307342529297   Valid loss: 72.81910705566406
#  71%|███████▏  | 15/21 [00:31<00:12,  2.09s/it]
# Epoch: 1   Batch: 15 of size 128   Train loss: 74.4875259399414   Valid loss: 70.00391387939453
#  76%|███████▌  | 16/21 [00:33<00:10,  2.08s/it]
# Epoch: 1   Batch: 16 of size 128   Train loss: 73.18060302734375   Valid loss: 69.59856414794922
#  81%|████████  | 17/21 [00:35<00:08,  2.08s/it]
# Epoch: 1   Batch: 17 of size 128   Train loss: 70.19229125976562   Valid loss: 68.12389373779297
#  86%|████████▌ | 18/21 [00:37<00:06,  2.10s/it]
# Epoch: 1   Batch: 18 of size 128   Train loss: 68.04723358154297   Valid loss: 65.91658782958984
#  90%|█████████ | 19/21 [00:39<00:04,  2.10s/it]
# Epoch: 1   Batch: 19 of size 128   Train loss: 67.00145721435547   Valid loss: 64.9385757446289
#  95%|█████████▌| 20/21 [00:41<00:02,  2.09s/it]
# Epoch: 1   Batch: 20 of size 128   Train loss: 65.87439727783203   Valid loss: 62.448062896728516
# 100%|██████████| 21/21 [00:42<00:00,  2.01s/it]
# Epoch: 1   Batch: 21 of size 128   Train loss: 52.33366012573242   Valid loss: 60.0837287902832
# ----------Training Ends-----------
# ----------Training MLP-----------
# 0.682 ----------saved-----------
# 0.7 ----------saved-----------
# C:\Users\caixu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1464: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(
# 0.714 ----------saved-----------
# 0.721 ----------saved-----------
# 0.722 ----------saved-----------
# 0.738 ----------saved-----------
# 0.747 ----------saved-----------
# 0.756 ----------saved-----------
# 0.419 ----------saved-----------
# 0.612 ----------saved-----------
# 0.643 ----------saved-----------
# 0.674 ----------saved-----------
# 0.689 ----------saved-----------
# 0.696 ----------saved-----------
# 0.708 ----------saved-----------
# 0.735 ----------saved-----------
# 0.749 ----------saved-----------
# 0.75 ----------saved-----------
# 0.755 ----------saved-----------
# 0.758 ----------saved-----------
# 0.762 ----------saved-----------
# 0.764 ----------saved-----------
# 0.772 ----------saved-----------
# 0.775 ----------saved-----------
# 0.776 ----------saved-----------
# 0.777 ----------saved-----------
# 0.782 ----------saved-----------
# 0.784 ----------saved-----------
# 0.786 ----------saved-----------
# ----------Training Ends-----------

# %%
IM.print_accuracy(dm, Araw, device_name = 'cpu')
# Out:
# GCN accuracy:
# device set to cuda
# threshold: 0.05  validation loss: 0.184 F1 accuracy 0.599 Precision accuracy 0.471 Recall accuracy 0.824 AUC accuracy: 0.917
# device set to cuda
# threshold: 0.1  validation loss: 0.184 F1 accuracy 0.668 Precision accuracy 0.584 Recall accuracy 0.78 AUC accuracy: 0.917
# device set to cuda
# threshold: 0.15  validation loss: 0.184 F1 accuracy 0.707 Precision accuracy 0.673 Recall accuracy 0.746 AUC accuracy: 0.917
# device set to cuda
# threshold: 0.2  validation loss: 0.184 F1 accuracy 0.725 Precision accuracy 0.718 Recall accuracy 0.732 AUC accuracy: 0.917
# device set to cuda
# threshold: 0.25  validation loss: 0.184 F1 accuracy 0.726 Precision accuracy 0.753 Recall accuracy 0.702 AUC accuracy: 0.917
# device set to cuda
# threshold: 0.3  validation loss: 0.184 F1 accuracy 0.747 Precision accuracy 0.813 Recall accuracy 0.692 AUC accuracy: 0.917
# device set to cuda
# threshold: 0.35  validation loss: 0.184 F1 accuracy 0.756 Precision accuracy 0.855 Recall accuracy 0.678 AUC accuracy: 0.917
# device set to cuda
# threshold: 0